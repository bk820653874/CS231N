# %% [markdown]
# # 两层神经网络
# ### 每个神经元用 tanh 函数激活，目前考虑需要对数据预处理：归一化，PCA和白化
# ### 权重初始化考虑 Kaiming He 的方法，
# ### 要加入L2正则项（暂时不用）
# ### 对每个神经元模块化设计

# %%
# 获取 CIFAR-10 数据集，并且处理成为train,validation,test 三部分
import numpy as np
import torch
import random
import pickle
import matplotlib.pyplot as plt
# 加载 CIFAR-10 数据集
# 这里使用的是CIFAR-10 的 data_batch_1 共一万个数据，我自己划分为 train,validation,test 三部分
# 前 6000 为training set，接着3000为 validation set 最后1000为 test set

def load_train_data(filename):
    with open(filename,'rb') as f:
        datadict = pickle.load(f,encoding = 'latin1')
        X = datadict['data']
        Y = datadict['labels']
        X = X.reshape(10000,3,32,32)
        Y = np.array(Y)
        return X,Y
    
    
root = 'data_batch_1'
(data, labels) = load_train_data(root)

train_set = data[0:3000]
train_labels = labels[0:3000]

val_set = data[6000:7000]
val_labels = labels[6000:7000]

test_set = data[9000:9500]
test_labels = labels[9000:9500]

# %%
# 对训练集进行预处理
# 数据可视化
data = train_set[0].T
plt.figure()
plt.imshow(data)
plt.show()

## 归一化
train_set = train_set - np.mean(train_set,axis = 0)
train_set = train_set / np.std(train_set,axis = 0)

# 数据可视化
data = train_set[0].T
plt.figure()
plt.imshow(data)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
## PCA 降维和白化
# 经过了归一化处理后，数据已经是零均值了,白化有点问题，暂时取消
train_set = train_set.reshape((train_set.shape[0],3072))
cov = np.dot(train_set.T,train_set) / train_set.shape[0] # 协方差矩阵,是半正定的 3072 * 3072
U,S,V = np.linalg.svd(cov)  # SVD 分解,U是对应的特征向量，S是特征值对角阵且由大到小排列
# 选择主成分个个数为 16 * 16 * 3，组成降维矩阵 P
train_set = np.dot(train_set,U[:,:144])
#train_set = train_set / np.sqrt(S[:] + 0)

# 数据可视化,观察降维结果
datas = train_set.dot(U[:,:144].T)
data = datas[0].reshape(3,32,32).T
print(np.shape(data))
plt.figure()
img = data
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (32, 32, 3)

# %%
## 两层神经网络搭建
## 太难写了，还是用 torch 框架吧
import torch
from torch.autograd import Variable
import torch.nn.functional as F
class two_layers_neural_networks(torch.nn.Module):
    def __init__(self,n_feature,n_hidden,n_output):
        super(two_layers_neural_networks, self).__init__()
        self.hidden = torch.nn.Linear(n_feature, n_hidden)
        self.output = torch.nn.Linear(n_hidden, 10)
        
    def forward(self, train_set):
        data = F.softmax(self.hidden(train_set))
        data = self.output(data)
        return data

# %%
## 初始化权重
# weight = 
# bias = 
# rate = 
# iteration = 
print(np.shape(train_set))
net = two_layers_neural_networks(144,10,10)
print(net)
# Out:
# (3000, 144)
# two_layers_neural_networks(
#   (hidden): Linear(in_features=144, out_features=10, bias=True)
#   (output): Linear(in_features=10, out_features=10, bias=True)
# )

# %%
optimizer = torch.optim.SGD(net.parameters(),lr=0.5)
loss_func = torch.nn.CrossEntropyLoss()
train_labels = torch.tensor(train_labels, dtype=torch.long)
train_set = torch.tensor(train_set, dtype=torch.float32)
x, y = Variable(train_set), Variable(train_labels)

# 开始训练
for iteration in range(10000):
    prediction = net(train_set)
    #prediction = torch.max(F.softmax(out),1)[1]
    
    loss = loss_func(prediction,train_labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print('iteration:\t%s\tloss:\t%s\n' % (iteration, loss.data))
# Out:
# iteration:	0	loss:	tensor(2.3099)
#
# iteration:	1	loss:	tensor(2.2992)
#
# iteration:	2	loss:	tensor(2.2913)
#
# iteration:	3	loss:	tensor(2.2848)
#
# iteration:	4	loss:	tensor(2.2789)
#
# iteration:	5	loss:	tensor(2.2735)
#
# iteration:	6	loss:	tensor(2.2684)
# E:\Anaconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   del sys.path[0]
# iteration:	7	loss:	tensor(2.2635)
#
# iteration:	8	loss:	tensor(2.2588)
#
# iteration:	9	loss:	tensor(2.2544)
#
# iteration:	10	loss:	tensor(2.2501)
#
# iteration:	11	loss:	tensor(2.2458)
#
# iteration:	12	loss:	tensor(2.2417)
#
# iteration:	13	loss:	tensor(2.2376)
#
# iteration:	14	loss:	tensor(2.2337)
#
# iteration:	15	loss:	tensor(2.2298)
#
# iteration:	16	loss:	tensor(2.2259)
#
# iteration:	17	loss:	tensor(2.2222)
#
# iteration:	18	loss:	tensor(2.2184)
#
# iteration:	19	loss:	tensor(2.2146)
#
# iteration:	20	loss:	tensor(2.2108)
#
# iteration:	21	loss:	tensor(2.2070)
#
# iteration:	22	loss:	tensor(2.2031)
#
# iteration:	23	loss:	tensor(2.1993)
#
# iteration:	24	loss:	tensor(2.1954)
#
# iteration:	25	loss:	tensor(2.1916)
#
# iteration:	26	loss:	tensor(2.1877)
#
# iteration:	27	loss:	tensor(2.1839)
#
# iteration:	28	loss:	tensor(2.1801)
#
# iteration:	29	loss:	tensor(2.1762)
#
# iteration:	30	loss:	tensor(2.1724)
#
# iteration:	31	loss:	tensor(2.1685)
#
# iteration:	32	loss:	tensor(2.1646)
#
# iteration:	33	loss:	tensor(2.1608)
#
# iteration:	34	loss:	tensor(2.1569)
#
# iteration:	35	loss:	tensor(2.1531)
#
# iteration:	36	loss:	tensor(2.1492)
#
# iteration:	37	loss:	tensor(2.1454)
#
# iteration:	38	loss:	tensor(2.1416)
#
# iteration:	39	loss:	tensor(2.1378)
#
# iteration:	40	loss:	tensor(2.1340)
#
# iteration:	41	loss:	tensor(2.1302)
#
# iteration:	42	loss:	tensor(2.1263)
#
# iteration:	43	loss:	tensor(2.1225)
#
# iteration:	44	loss:	tensor(2.1187)
#
# iteration:	45	loss:	tensor(2.1148)
#
# iteration:	46	loss:	tensor(2.1110)
#
# iteration:	47	loss:	tensor(2.1071)
#
# iteration:	48	loss:	tensor(2.1033)
#
# iteration:	49	loss:	tensor(2.0995)
#
# iteration:	50	loss:	tensor(2.0957)
#
# iteration:	51	loss:	tensor(2.0919)
#
# iteration:	52	loss:	tensor(2.0881)
#
# iteration:	53	loss:	tensor(2.0844)
#
# iteration:	54	loss:	tensor(2.0806)
#
# iteration:	55	loss:	tensor(2.0769)
#
# iteration:	56	loss:	tensor(2.0732)
#
# iteration:	57	loss:	tensor(2.0695)
#
# iteration:	58	loss:	tensor(2.0660)
#
# iteration:	59	loss:	tensor(2.0628)
#
# iteration:	60	loss:	tensor(2.0605)
#
# iteration:	61	loss:	tensor(2.0593)
#
# iteration:	62	loss:	tensor(2.0521)
#
# iteration:	63	loss:	tensor(2.0500)
#
# iteration:	64	loss:	tensor(2.0472)
#
# iteration:	65	loss:	tensor(2.0458)
#
# iteration:	66	loss:	tensor(2.0375)
#
# iteration:	67	loss:	tensor(2.0342)
#
# iteration:	68	loss:	tensor(2.0317)
#
# iteration:	69	loss:	tensor(2.0310)
#
# iteration:	70	loss:	tensor(2.0244)
#
# iteration:	71	loss:	tensor(2.0231)
#
# iteration:	72	loss:	tensor(2.0186)
#
# iteration:	73	loss:	tensor(2.0179)
#
# iteration:	74	loss:	tensor(2.0102)
#
# iteration:	75	loss:	tensor(2.0076)
#
# iteration:	76	loss:	tensor(2.0059)
#
# iteration:	77	loss:	tensor(2.0058)
#
# iteration:	78	loss:	tensor(1.9968)
#
# iteration:	79	loss:	tensor(1.9935)
#
# iteration:	80	loss:	tensor(1.9906)
#
# iteration:	81	loss:	tensor(1.9887)
#
# iteration:	82	loss:	tensor(1.9883)
#
# iteration:	83	loss:	tensor(1.9894)
#
# iteration:	84	loss:	tensor(1.9794)
#
# iteration:	85	loss:	tensor(1.9769)
#
# iteration:	86	loss:	tensor(1.9753)
#
# iteration:	87	loss:	tensor(1.9720)
#
# iteration:	88	loss:	tensor(1.9704)
#
# iteration:	89	loss:	tensor(1.9644)
#
# iteration:	90	loss:	tensor(1.9634)
#
# iteration:	91	loss:	tensor(1.9591)
#
# iteration:	92	loss:	tensor(1.9596)
#
# iteration:	93	loss:	tensor(1.9519)
#
# iteration:	94	loss:	tensor(1.9503)
#
# iteration:	95	loss:	tensor(1.9497)
#
# iteration:	96	loss:	tensor(1.9517)
#
# iteration:	97	loss:	tensor(1.9414)
#
# iteration:	98	loss:	tensor(1.9391)
#
# iteration:	99	loss:	tensor(1.9358)
#
# iteration:	100	loss:	tensor(1.9340)
#
# iteration:	101	loss:	tensor(1.9311)
#
# iteration:	102	loss:	tensor(1.9285)
#
# iteration:	103	loss:	tensor(1.9273)
#
# iteration:	104	loss:	tensor(1.9258)
#
# iteration:	105	loss:	tensor(1.9264)
#
# iteration:	106	loss:	tensor(1.9260)
#
# iteration:	107	loss:	tensor(1.9200)
#
# iteration:	108	loss:	tensor(1.9199)
#
# iteration:	109	loss:	tensor(1.9213)
#
# iteration:	110	loss:	tensor(1.9148)
#
# iteration:	111	loss:	tensor(1.9074)
#
# iteration:	112	loss:	tensor(1.9068)
#
# iteration:	113	loss:	tensor(1.9029)
#
# iteration:	114	loss:	tensor(1.9045)
#
# iteration:	115	loss:	tensor(1.8971)
#
# iteration:	116	loss:	tensor(1.8973)
#
# iteration:	117	loss:	tensor(1.8930)
#
# iteration:	118	loss:	tensor(1.8948)
#
# iteration:	119	loss:	tensor(1.8865)
#
# iteration:	120	loss:	tensor(1.8878)
#
# iteration:	121	loss:	tensor(1.8810)
#
# iteration:	122	loss:	tensor(1.8849)
#
# iteration:	123	loss:	tensor(1.8749)
#
# iteration:	124	loss:	tensor(1.8793)
#
# iteration:	125	loss:	tensor(1.8726)
#
# iteration:	126	loss:	tensor(1.8814)
#
# iteration:	127	loss:	tensor(1.8688)
#
# iteration:	128	loss:	tensor(1.8699)
#
# iteration:	129	loss:	tensor(1.8684)
#
# iteration:	130	loss:	tensor(1.8676)
#
# iteration:	131	loss:	tensor(1.8682)
#
# iteration:	132	loss:	tensor(1.8727)
#
# iteration:	133	loss:	tensor(1.8591)
#
# iteration:	134	loss:	tensor(1.8566)
#
# iteration:	135	loss:	tensor(1.8530)
#
# iteration:	136	loss:	tensor(1.8532)
#
# iteration:	137	loss:	tensor(1.8480)
#
# iteration:	138	loss:	tensor(1.8446)
#
# iteration:	139	loss:	tensor(1.8415)
#
# iteration:	140	loss:	tensor(1.8422)
#
# iteration:	141	loss:	tensor(1.8401)
#
# iteration:	142	loss:	tensor(1.8359)
#
# iteration:	143	loss:	tensor(1.8326)
#
# iteration:	144	loss:	tensor(1.8466)
#
# iteration:	145	loss:	tensor(1.8488)
#
# iteration:	146	loss:	tensor(1.8468)
#
# iteration:	147	loss:	tensor(1.8313)
#
# iteration:	148	loss:	tensor(1.8325)
#
# iteration:	149	loss:	tensor(1.8291)
#
# iteration:	150	loss:	tensor(1.8236)
#
# iteration:	151	loss:	tensor(1.8202)
#
# iteration:	152	loss:	tensor(1.8247)
#
# iteration:	153	loss:	tensor(1.8260)
#
# iteration:	154	loss:	tensor(1.8181)
#
# iteration:	155	loss:	tensor(1.8111)
#
# iteration:	156	loss:	tensor(1.8137)
#
# iteration:	157	loss:	tensor(1.8091)
#
# iteration:	158	loss:	tensor(1.8157)
#
# iteration:	159	loss:	tensor(1.8086)
#
# iteration:	160	loss:	tensor(1.8196)
#
# iteration:	161	loss:	tensor(1.8069)
#
# iteration:	162	loss:	tensor(1.8185)
#
# iteration:	163	loss:	tensor(1.7986)
#
# iteration:	164	loss:	tensor(1.8060)
#
# iteration:	165	loss:	tensor(1.7942)
#
# iteration:	166	loss:	tensor(1.8021)
#
# iteration:	167	loss:	tensor(1.7848)
#
# iteration:	168	loss:	tensor(1.7839)
#
# iteration:	169	loss:	tensor(1.7783)
#
# iteration:	170	loss:	tensor(1.7834)
#
# iteration:	171	loss:	tensor(1.7940)
#
# iteration:	172	loss:	tensor(1.8032)
#
# iteration:	173	loss:	tensor(1.7964)
#
# iteration:	174	loss:	tensor(1.7994)
#
# iteration:	175	loss:	tensor(1.7823)
#
# iteration:	176	loss:	tensor(1.7805)
#
# iteration:	177	loss:	tensor(1.7834)
#
# iteration:	178	loss:	tensor(1.7801)
#
# iteration:	179	loss:	tensor(1.7780)
#
# iteration:	180	loss:	tensor(1.7805)
#
# iteration:	181	loss:	tensor(1.7791)
#
# iteration:	182	loss:	tensor(1.7830)
#
# iteration:	183	loss:	tensor(1.7821)
#
# iteration:	184	loss:	tensor(1.7894)
#
# iteration:	185	loss:	tensor(1.7759)
#
# iteration:	186	loss:	tensor(1.7775)
#
# iteration:	187	loss:	tensor(1.7675)
#
# iteration:	188	loss:	tensor(1.7706)
#
# iteration:	189	loss:	tensor(1.7653)
#
# iteration:	190	loss:	tensor(1.7642)
#
# iteration:	191	loss:	tensor(1.7612)
#
# iteration:	192	loss:	tensor(1.7599)
#
# iteration:	193	loss:	tensor(1.7592)
#
# iteration:	194	loss:	tensor(1.7603)
#
# iteration:	195	loss:	tensor(1.7590)
#
# iteration:	196	loss:	tensor(1.7652)
#
# iteration:	197	loss:	tensor(1.7548)
#
# iteration:	198	loss:	tensor(1.7573)
#
# iteration:	199	loss:	tensor(1.7556)
#
# iteration:	200	loss:	tensor(1.7550)
#
# iteration:	201	loss:	tensor(1.7617)
#
# iteration:	202	loss:	tensor(1.7439)
#
# iteration:	203	loss:	tensor(1.7528)
#
# iteration:	204	loss:	tensor(1.7316)
#
# iteration:	205	loss:	tensor(1.7462)
#
# iteration:	206	loss:	tensor(1.7264)
#
# iteration:	207	loss:	tensor(1.7410)
#
# iteration:	208	loss:	tensor(1.7385)
#
# iteration:	209	loss:	tensor(1.7634)
#
# iteration:	210	loss:	tensor(1.7342)
#
# iteration:	211	loss:	tensor(1.7321)
#
# iteration:	212	loss:	tensor(1.7263)
#
# iteration:	213	loss:	tensor(1.7256)
#
# iteration:	214	loss:	tensor(1.7311)
#
# iteration:	215	loss:	tensor(1.7178)
#
# iteration:	216	loss:	tensor(1.7227)
#
# iteration:	217	loss:	tensor(1.7390)
#
# iteration:	218	loss:	tensor(1.7456)
#
# iteration:	219	loss:	tensor(1.7628)
#
# iteration:	220	loss:	tensor(1.7225)
#
# iteration:	221	loss:	tensor(1.7193)
#
# iteration:	222	loss:	tensor(1.7192)
#
# iteration:	223	loss:	tensor(1.7134)
#
# iteration:	224	loss:	tensor(1.7209)
#
# iteration:	225	loss:	tensor(1.7214)
#
# iteration:	226	loss:	tensor(1.7231)
#
# iteration:	227	loss:	tensor(1.7293)
#
# iteration:	228	loss:	tensor(1.7388)
#
# iteration:	229	loss:	tensor(1.7220)
#
# iteration:	230	loss:	tensor(1.7385)
#
# iteration:	231	loss:	tensor(1.7052)
#
# iteration:	232	loss:	tensor(1.7197)
#
# iteration:	233	loss:	tensor(1.7025)
#
# iteration:	234	loss:	tensor(1.7283)
#
# iteration:	235	loss:	tensor(1.6955)
#
# iteration:	236	loss:	tensor(1.7057)
#
# iteration:	237	loss:	tensor(1.7144)
#
# iteration:	238	loss:	tensor(1.7001)
#
# iteration:	239	loss:	tensor(1.6958)
#
# iteration:	240	loss:	tensor(1.7154)
#
# iteration:	241	loss:	tensor(1.6939)
#
# iteration:	242	loss:	tensor(1.6982)
#
# iteration:	243	loss:	tensor(1.7119)
#
# iteration:	244	loss:	tensor(1.7210)
#
# iteration:	245	loss:	tensor(1.7017)
#
# iteration:	246	loss:	tensor(1.7132)
#
# iteration:	247	loss:	tensor(1.7058)
#
# iteration:	248	loss:	tensor(1.7266)
#
# iteration:	249	loss:	tensor(1.6989)
#
# iteration:	250	loss:	tensor(1.6910)
#
# iteration:	251	loss:	tensor(1.6822)
#
# iteration:	252	loss:	tensor(1.6732)
#
# iteration:	253	loss:	tensor(1.6860)
#
# iteration:	254	loss:	tensor(1.6659)
#
# iteration:	255	loss:	tensor(1.6709)
#
# iteration:	256	loss:	tensor(1.6938)
#
# iteration:	257	loss:	tensor(1.6780)
#
# iteration:	258	loss:	tensor(1.7040)
#
# iteration:	259	loss:	tensor(1.7020)
#
# iteration:	260	loss:	tensor(1.7252)
# iteration:	261	loss:	tensor(1.6957)
#
# iteration:	262	loss:	tensor(1.7013)
#
# iteration:	263	loss:	tensor(1.6909)
#
# iteration:	264	loss:	tensor(1.6969)
#
# iteration:	265	loss:	tensor(1.6930)
#
# iteration:	266	loss:	tensor(1.6925)
#
# iteration:	267	loss:	tensor(1.6746)
#
# iteration:	268	loss:	tensor(1.6945)
#
# iteration:	269	loss:	tensor(1.6866)
#
# iteration:	270	loss:	tensor(1.6740)
#
# iteration:	271	loss:	tensor(1.6650)
#
# iteration:	272	loss:	tensor(1.6732)
#
# iteration:	273	loss:	tensor(1.6712)
#
# iteration:	274	loss:	tensor(1.6919)
#
# iteration:	275	loss:	tensor(1.7070)
#
# iteration:	276	loss:	tensor(1.6596)
#
# iteration:	277	loss:	tensor(1.6538)
#
# iteration:	278	loss:	tensor(1.6674)
#
# iteration:	279	loss:	tensor(1.6432)
#
# iteration:	280	loss:	tensor(1.6570)
#
# iteration:	281	loss:	tensor(1.6844)
#
# iteration:	282	loss:	tensor(1.6649)
#
# iteration:	283	loss:	tensor(1.6834)
#
# iteration:	284	loss:	tensor(1.6705)
#
# iteration:	285	loss:	tensor(1.7026)
#
# iteration:	286	loss:	tensor(1.6899)
#
# iteration:	287	loss:	tensor(1.7103)
#
# iteration:	288	loss:	tensor(1.6771)
#
# iteration:	289	loss:	tensor(1.6788)
#
# iteration:	290	loss:	tensor(1.6665)
#
# iteration:	291	loss:	tensor(1.6630)
#
# iteration:	292	loss:	tensor(1.6597)
#
# iteration:	293	loss:	tensor(1.6494)
#
# iteration:	294	loss:	tensor(1.6508)
#
# iteration:	295	loss:	tensor(1.6449)
#
# iteration:	296	loss:	tensor(1.6494)
#
# iteration:	297	loss:	tensor(1.6492)
#
# iteration:	298	loss:	tensor(1.6641)
#
# iteration:	299	loss:	tensor(1.6915)
#
# iteration:	300	loss:	tensor(1.6554)
#
# iteration:	301	loss:	tensor(1.6504)
#
# iteration:	302	loss:	tensor(1.6712)
#
# iteration:	303	loss:	tensor(1.6374)
#
# iteration:	304	loss:	tensor(1.6460)
#
# iteration:	305	loss:	tensor(1.6330)
#
# iteration:	306	loss:	tensor(1.6465)
#
# iteration:	307	loss:	tensor(1.6307)
#
# iteration:	308	loss:	tensor(1.6414)
#
# iteration:	309	loss:	tensor(1.6319)
#
# iteration:	310	loss:	tensor(1.6403)
#
# iteration:	311	loss:	tensor(1.6443)
#
# iteration:	312	loss:	tensor(1.6630)
#
# iteration:	313	loss:	tensor(1.6845)
#
# iteration:	314	loss:	tensor(1.6412)
#
# iteration:	315	loss:	tensor(1.6232)
#
# iteration:	316	loss:	tensor(1.6405)
#
# iteration:	317	loss:	tensor(1.6410)
#
# iteration:	318	loss:	tensor(1.6415)
#
# iteration:	319	loss:	tensor(1.6849)
#
# iteration:	320	loss:	tensor(1.6428)
#
# iteration:	321	loss:	tensor(1.6661)
#
# iteration:	322	loss:	tensor(1.6528)
#
# iteration:	323	loss:	tensor(1.6805)
#
# iteration:	324	loss:	tensor(1.6459)
#
# iteration:	325	loss:	tensor(1.6658)
#
# iteration:	326	loss:	tensor(1.6407)
#
# iteration:	327	loss:	tensor(1.6636)
#
# iteration:	328	loss:	tensor(1.6291)
#
# iteration:	329	loss:	tensor(1.6265)
#
# iteration:	330	loss:	tensor(1.6202)
#
# iteration:	331	loss:	tensor(1.6192)
#
# iteration:	332	loss:	tensor(1.6372)
#
# iteration:	333	loss:	tensor(1.6226)
#
# iteration:	334	loss:	tensor(1.6204)
#
# iteration:	335	loss:	tensor(1.6612)
#
# iteration:	336	loss:	tensor(1.6103)
#
# iteration:	337	loss:	tensor(1.6160)
#
# iteration:	338	loss:	tensor(1.6110)
#
# iteration:	339	loss:	tensor(1.6446)
#
# iteration:	340	loss:	tensor(1.6145)
#
# iteration:	341	loss:	tensor(1.6433)
#
# iteration:	342	loss:	tensor(1.6197)
#
# iteration:	343	loss:	tensor(1.6577)
#
# iteration:	344	loss:	tensor(1.6147)
#
# iteration:	345	loss:	tensor(1.6328)
#
# iteration:	346	loss:	tensor(1.6320)
#
# iteration:	347	loss:	tensor(1.6799)
#
# iteration:	348	loss:	tensor(1.6054)
#
# iteration:	349	loss:	tensor(1.6258)
#
# iteration:	350	loss:	tensor(1.5960)
#
# iteration:	351	loss:	tensor(1.6061)
#
# iteration:	352	loss:	tensor(1.6244)
#
# iteration:	353	loss:	tensor(1.6397)
#
# iteration:	354	loss:	tensor(1.6050)
#
# iteration:	355	loss:	tensor(1.6171)
#
# iteration:	356	loss:	tensor(1.6205)
#
# iteration:	357	loss:	tensor(1.6431)
#
# iteration:	358	loss:	tensor(1.6470)
#
# iteration:	359	loss:	tensor(1.7081)
#
# iteration:	360	loss:	tensor(1.6122)
#
# iteration:	361	loss:	tensor(1.6209)
#
# iteration:	362	loss:	tensor(1.6265)
#
# iteration:	363	loss:	tensor(1.6348)
#
# iteration:	364	loss:	tensor(1.6166)
#
# iteration:	365	loss:	tensor(1.6413)
#
# iteration:	366	loss:	tensor(1.6308)
#
# iteration:	367	loss:	tensor(1.6132)
#
# iteration:	368	loss:	tensor(1.6075)
#
# iteration:	369	loss:	tensor(1.6172)
#
# iteration:	370	loss:	tensor(1.6416)
#
# iteration:	371	loss:	tensor(1.6062)
#
# iteration:	372	loss:	tensor(1.6219)
#
# iteration:	373	loss:	tensor(1.6013)
#
# iteration:	374	loss:	tensor(1.6187)
#
# iteration:	375	loss:	tensor(1.6026)
#
# iteration:	376	loss:	tensor(1.6133)
#
# iteration:	377	loss:	tensor(1.6153)
#
# iteration:	378	loss:	tensor(1.6379)
#
# iteration:	379	loss:	tensor(1.6145)
#
# iteration:	380	loss:	tensor(1.6212)
#
# iteration:	381	loss:	tensor(1.6049)
#
# iteration:	382	loss:	tensor(1.6111)
#
# iteration:	383	loss:	tensor(1.6232)
#
# iteration:	384	loss:	tensor(1.5979)
#
# iteration:	385	loss:	tensor(1.5972)
#
# iteration:	386	loss:	tensor(1.6260)
#
# iteration:	387	loss:	tensor(1.5938)
#
# iteration:	388	loss:	tensor(1.6012)
#
# iteration:	389	loss:	tensor(1.6023)
#
# iteration:	390	loss:	tensor(1.6007)
#
# iteration:	391	loss:	tensor(1.6066)
#
# iteration:	392	loss:	tensor(1.6210)
#
# iteration:	393	loss:	tensor(1.6069)
#
# iteration:	394	loss:	tensor(1.6293)
#
# iteration:	395	loss:	tensor(1.6023)
#
# iteration:	396	loss:	tensor(1.6122)
#
# iteration:	397	loss:	tensor(1.6000)
#
# iteration:	398	loss:	tensor(1.6153)
#
# iteration:	399	loss:	tensor(1.6082)
#
# iteration:	400	loss:	tensor(1.6280)
#
# iteration:	401	loss:	tensor(1.5947)
#
# iteration:	402	loss:	tensor(1.5945)
#
# iteration:	403	loss:	tensor(1.5974)
#
# iteration:	404	loss:	tensor(1.6090)
#
# iteration:	405	loss:	tensor(1.6024)
#
# iteration:	406	loss:	tensor(1.6261)
#
# iteration:	407	loss:	tensor(1.5936)
#
# iteration:	408	loss:	tensor(1.5806)
#
# iteration:	409	loss:	tensor(1.5736)
#
# iteration:	410	loss:	tensor(1.5685)
#
# iteration:	411	loss:	tensor(1.5814)
#
# iteration:	412	loss:	tensor(1.5850)
#
# iteration:	413	loss:	tensor(1.5814)
#
# iteration:	414	loss:	tensor(1.5906)
#
# iteration:	415	loss:	tensor(1.5735)
#
# iteration:	416	loss:	tensor(1.5744)
#
# iteration:	417	loss:	tensor(1.5870)
#
# iteration:	418	loss:	tensor(1.5890)
#
# iteration:	419	loss:	tensor(1.6222)
#
# iteration:	420	loss:	tensor(1.5779)
#
# iteration:	421	loss:	tensor(1.5827)
#
# iteration:	422	loss:	tensor(1.5685)
#
# iteration:	423	loss:	tensor(1.5791)
#
# iteration:	424	loss:	tensor(1.5935)
#
# iteration:	425	loss:	tensor(1.6284)
#
# iteration:	426	loss:	tensor(1.5812)
#
# iteration:	427	loss:	tensor(1.5672)
#
# iteration:	428	loss:	tensor(1.5768)
#
# iteration:	429	loss:	tensor(1.5566)
#
# iteration:	430	loss:	tensor(1.5710)
#
# iteration:	431	loss:	tensor(1.5656)
#
# iteration:	432	loss:	tensor(1.5840)
#
# iteration:	433	loss:	tensor(1.5908)
#
# iteration:	434	loss:	tensor(1.6072)
#
# iteration:	435	loss:	tensor(1.6367)
#
# iteration:	436	loss:	tensor(1.5741)
#
# iteration:	437	loss:	tensor(1.5671)
#
# iteration:	438	loss:	tensor(1.5722)
#
# iteration:	439	loss:	tensor(1.5715)
#
# iteration:	440	loss:	tensor(1.5693)
#
# iteration:	441	loss:	tensor(1.5983)
#
# iteration:	442	loss:	tensor(1.5913)
#
# iteration:	443	loss:	tensor(1.6511)
#
# iteration:	444	loss:	tensor(1.5854)
#
# iteration:	445	loss:	tensor(1.5983)
#
# iteration:	446	loss:	tensor(1.5732)
#
# iteration:	447	loss:	tensor(1.6093)
#
# iteration:	448	loss:	tensor(1.5632)
#
# iteration:	449	loss:	tensor(1.5775)
#
# iteration:	450	loss:	tensor(1.5563)
#
# iteration:	451	loss:	tensor(1.5627)
#
# iteration:	452	loss:	tensor(1.5588)
#
# iteration:	453	loss:	tensor(1.5616)
#
# iteration:	454	loss:	tensor(1.5571)
#
# iteration:	455	loss:	tensor(1.5790)
#
# iteration:	456	loss:	tensor(1.5553)
#
# iteration:	457	loss:	tensor(1.5702)
#
# iteration:	458	loss:	tensor(1.5609)
#
# iteration:	459	loss:	tensor(1.5852)
#
# iteration:	460	loss:	tensor(1.5841)
#
# iteration:	461	loss:	tensor(1.6223)
#
# iteration:	462	loss:	tensor(1.5502)
#
# iteration:	463	loss:	tensor(1.5513)
#
# iteration:	464	loss:	tensor(1.5471)
#
# iteration:	465	loss:	tensor(1.5466)
#
# iteration:	466	loss:	tensor(1.5498)
#
# iteration:	467	loss:	tensor(1.5583)
#
# iteration:	468	loss:	tensor(1.5658)
#
# iteration:	469	loss:	tensor(1.5592)
#
# iteration:	470	loss:	tensor(1.5958)
#
# iteration:	471	loss:	tensor(1.5563)
#
# iteration:	472	loss:	tensor(1.5683)
#
# iteration:	473	loss:	tensor(1.5690)
#
# iteration:	474	loss:	tensor(1.5903)
#
# iteration:	475	loss:	tensor(1.5942)
#
# iteration:	476	loss:	tensor(1.5769)
#
# iteration:	477	loss:	tensor(1.5719)
#
# iteration:	478	loss:	tensor(1.5619)
#
# iteration:	479	loss:	tensor(1.5774)
#
# iteration:	480	loss:	tensor(1.5424)
#
# iteration:	481	loss:	tensor(1.5521)
#
# iteration:	482	loss:	tensor(1.5629)
#
# iteration:	483	loss:	tensor(1.5628)
#
# iteration:	484	loss:	tensor(1.6102)
#
# iteration:	485	loss:	tensor(1.5436)
#
# iteration:	486	loss:	tensor(1.5392)
#
# iteration:	487	loss:	tensor(1.5539)
#
# iteration:	488	loss:	tensor(1.5394)
#
# iteration:	489	loss:	tensor(1.5502)
#
# iteration:	490	loss:	tensor(1.5531)
#
# iteration:	491	loss:	tensor(1.5650)
#
# iteration:	492	loss:	tensor(1.5863)
#
# iteration:	493	loss:	tensor(1.5968)
#
# iteration:	494	loss:	tensor(1.6401)
#
# iteration:	495	loss:	tensor(1.5661)
#
# iteration:	496	loss:	tensor(1.5672)
#
# iteration:	497	loss:	tensor(1.5491)
#
# iteration:	498	loss:	tensor(1.5550)
#
# iteration:	499	loss:	tensor(1.5378)
#
# iteration:	500	loss:	tensor(1.5717)
#
# iteration:	501	loss:	tensor(1.5559)
#
# iteration:	502	loss:	tensor(1.5685)
#
# iteration:	503	loss:	tensor(1.5796)
#
# iteration:	504	loss:	tensor(1.5513)
#
# iteration:	505	loss:	tensor(1.5369)
#
# iteration:	506	loss:	tensor(1.5482)
#
# iteration:	507	loss:	tensor(1.5441)
#
# iteration:	508	loss:	tensor(1.5378)
#
# iteration:	509	loss:	tensor(1.5369)
#
# iteration:	510	loss:	tensor(1.5392)
#
# iteration:	511	loss:	tensor(1.5324)
#
# iteration:	512	loss:	tensor(1.5493)
#
# iteration:	513	loss:	tensor(1.5382)
#
# iteration:	514	loss:	tensor(1.5499)
#
# iteration:	515	loss:	tensor(1.5757)
#
# iteration:	516	loss:	tensor(1.5402)
#
# iteration:	517	loss:	tensor(1.5437)
#
# iteration:	518	loss:	tensor(1.5388)
#
# iteration:	519	loss:	tensor(1.5833)
# iteration:	520	loss:	tensor(1.5261)
#
# iteration:	521	loss:	tensor(1.5289)
#
# iteration:	522	loss:	tensor(1.5445)
#
# iteration:	523	loss:	tensor(1.5298)
#
# iteration:	524	loss:	tensor(1.5371)
#
# iteration:	525	loss:	tensor(1.5441)
#
# iteration:	526	loss:	tensor(1.5304)
#
# iteration:	527	loss:	tensor(1.5277)
#
# iteration:	528	loss:	tensor(1.5366)
#
# iteration:	529	loss:	tensor(1.5457)
#
# iteration:	530	loss:	tensor(1.5361)
#
# iteration:	531	loss:	tensor(1.5531)
#
# iteration:	532	loss:	tensor(1.5717)
#
# iteration:	533	loss:	tensor(1.5726)
#
# iteration:	534	loss:	tensor(1.5726)
#
# iteration:	535	loss:	tensor(1.5630)
#
# iteration:	536	loss:	tensor(1.5226)
#
# iteration:	537	loss:	tensor(1.5489)
#
# iteration:	538	loss:	tensor(1.5191)
#
# iteration:	539	loss:	tensor(1.5345)
#
# iteration:	540	loss:	tensor(1.5465)
#
# iteration:	541	loss:	tensor(1.5333)
#
# iteration:	542	loss:	tensor(1.5432)
#
# iteration:	543	loss:	tensor(1.5543)
#
# iteration:	544	loss:	tensor(1.5895)
#
# iteration:	545	loss:	tensor(1.5379)
#
# iteration:	546	loss:	tensor(1.5312)
#
# iteration:	547	loss:	tensor(1.5442)
#
# iteration:	548	loss:	tensor(1.5208)
#
# iteration:	549	loss:	tensor(1.5150)
#
# iteration:	550	loss:	tensor(1.5435)
#
# iteration:	551	loss:	tensor(1.5269)
#
# iteration:	552	loss:	tensor(1.5712)
#
# iteration:	553	loss:	tensor(1.5245)
#
# iteration:	554	loss:	tensor(1.5668)
#
# iteration:	555	loss:	tensor(1.5240)
#
# iteration:	556	loss:	tensor(1.5506)
#
# iteration:	557	loss:	tensor(1.5249)
#
# iteration:	558	loss:	tensor(1.5640)
#
# iteration:	559	loss:	tensor(1.5297)
#
# iteration:	560	loss:	tensor(1.5597)
#
# iteration:	561	loss:	tensor(1.5500)
#
# iteration:	562	loss:	tensor(1.5400)
#
# iteration:	563	loss:	tensor(1.5346)
#
# iteration:	564	loss:	tensor(1.5496)
#
# iteration:	565	loss:	tensor(1.5393)
#
# iteration:	566	loss:	tensor(1.5577)
#
# iteration:	567	loss:	tensor(1.5444)
#
# iteration:	568	loss:	tensor(1.5574)
#
# iteration:	569	loss:	tensor(1.5394)
#
# iteration:	570	loss:	tensor(1.5334)
#
# iteration:	571	loss:	tensor(1.5211)
#
# iteration:	572	loss:	tensor(1.5144)
#
# iteration:	573	loss:	tensor(1.5277)
#
# iteration:	574	loss:	tensor(1.5217)
#
# iteration:	575	loss:	tensor(1.5223)
#
# iteration:	576	loss:	tensor(1.5290)
#
# iteration:	577	loss:	tensor(1.5132)
#
# iteration:	578	loss:	tensor(1.4991)
#
# iteration:	579	loss:	tensor(1.5037)
#
# iteration:	580	loss:	tensor(1.5007)
#
# iteration:	581	loss:	tensor(1.5200)
#
# iteration:	582	loss:	tensor(1.5007)
#
# iteration:	583	loss:	tensor(1.5112)
#
# iteration:	584	loss:	tensor(1.5277)
#
# iteration:	585	loss:	tensor(1.5408)
#
# iteration:	586	loss:	tensor(1.5324)
#
# iteration:	587	loss:	tensor(1.5606)
#
# iteration:	588	loss:	tensor(1.5499)
#
# iteration:	589	loss:	tensor(1.5963)
#
# iteration:	590	loss:	tensor(1.5287)
#
# iteration:	591	loss:	tensor(1.5096)
#
# iteration:	592	loss:	tensor(1.5323)
#
# iteration:	593	loss:	tensor(1.4988)
#
# iteration:	594	loss:	tensor(1.5106)
#
# iteration:	595	loss:	tensor(1.4973)
#
# iteration:	596	loss:	tensor(1.5239)
#
# iteration:	597	loss:	tensor(1.4971)
#
# iteration:	598	loss:	tensor(1.5305)
#
# iteration:	599	loss:	tensor(1.5140)
#
# iteration:	600	loss:	tensor(1.5917)
#
# iteration:	601	loss:	tensor(1.5244)
#
# iteration:	602	loss:	tensor(1.5666)
#
# iteration:	603	loss:	tensor(1.5076)
#
# iteration:	604	loss:	tensor(1.5230)
#
# iteration:	605	loss:	tensor(1.5380)
#
# iteration:	606	loss:	tensor(1.5211)
#
# iteration:	607	loss:	tensor(1.5156)
#
# iteration:	608	loss:	tensor(1.5795)
#
# iteration:	609	loss:	tensor(1.5228)
#
# iteration:	610	loss:	tensor(1.5846)
#
# iteration:	611	loss:	tensor(1.5045)
#
# iteration:	612	loss:	tensor(1.5146)
#
# iteration:	613	loss:	tensor(1.5070)
#
# iteration:	614	loss:	tensor(1.5372)
#
# iteration:	615	loss:	tensor(1.5025)
#
# iteration:	616	loss:	tensor(1.5335)
#
# iteration:	617	loss:	tensor(1.5036)
#
# iteration:	618	loss:	tensor(1.5327)
#
# iteration:	619	loss:	tensor(1.4895)
#
# iteration:	620	loss:	tensor(1.4958)
#
# iteration:	621	loss:	tensor(1.4930)
#
# iteration:	622	loss:	tensor(1.5133)
#
# iteration:	623	loss:	tensor(1.4927)
#
# iteration:	624	loss:	tensor(1.5029)
#
# iteration:	625	loss:	tensor(1.4908)
#
# iteration:	626	loss:	tensor(1.5185)
#
# iteration:	627	loss:	tensor(1.4950)
#
# iteration:	628	loss:	tensor(1.5213)
#
# iteration:	629	loss:	tensor(1.4896)
#
# iteration:	630	loss:	tensor(1.5016)
#
# iteration:	631	loss:	tensor(1.5150)
#
# iteration:	632	loss:	tensor(1.5013)
#
# iteration:	633	loss:	tensor(1.5065)
#
# iteration:	634	loss:	tensor(1.5296)
#
# iteration:	635	loss:	tensor(1.5229)
#
# iteration:	636	loss:	tensor(1.5299)
#
# iteration:	637	loss:	tensor(1.5436)
#
# iteration:	638	loss:	tensor(1.5625)
#
# iteration:	639	loss:	tensor(1.5303)
#
# iteration:	640	loss:	tensor(1.5873)
#
# iteration:	641	loss:	tensor(1.5037)
#
# iteration:	642	loss:	tensor(1.5186)
#
# iteration:	643	loss:	tensor(1.5272)
#
# iteration:	644	loss:	tensor(1.5245)
#
# iteration:	645	loss:	tensor(1.4948)
#
# iteration:	646	loss:	tensor(1.5164)
#
# iteration:	647	loss:	tensor(1.5094)
#
# iteration:	648	loss:	tensor(1.5227)
#
# iteration:	649	loss:	tensor(1.5354)
#
# iteration:	650	loss:	tensor(1.5317)
#
# iteration:	651	loss:	tensor(1.5340)
#
# iteration:	652	loss:	tensor(1.5740)
#
# iteration:	653	loss:	tensor(1.5249)
#
# iteration:	654	loss:	tensor(1.5018)
#
# iteration:	655	loss:	tensor(1.5017)
#
# iteration:	656	loss:	tensor(1.5145)
#
# iteration:	657	loss:	tensor(1.5082)
#
# iteration:	658	loss:	tensor(1.5003)
#
# iteration:	659	loss:	tensor(1.5160)
#
# iteration:	660	loss:	tensor(1.4939)
#
# iteration:	661	loss:	tensor(1.5034)
#
# iteration:	662	loss:	tensor(1.5129)
#
# iteration:	663	loss:	tensor(1.5139)
#
# iteration:	664	loss:	tensor(1.5310)
#
# iteration:	665	loss:	tensor(1.5698)
#
# iteration:	666	loss:	tensor(1.4988)
#
# iteration:	667	loss:	tensor(1.5009)
#
# iteration:	668	loss:	tensor(1.5134)
#
# iteration:	669	loss:	tensor(1.4955)
#
# iteration:	670	loss:	tensor(1.4979)
#
# iteration:	671	loss:	tensor(1.5177)
#
# iteration:	672	loss:	tensor(1.5276)
#
# iteration:	673	loss:	tensor(1.5060)
#
# iteration:	674	loss:	tensor(1.5225)
#
# iteration:	675	loss:	tensor(1.5073)
#
# iteration:	676	loss:	tensor(1.5191)
#
# iteration:	677	loss:	tensor(1.5090)
#
# iteration:	678	loss:	tensor(1.5076)
#
# iteration:	679	loss:	tensor(1.5031)
#
# iteration:	680	loss:	tensor(1.5208)
#
# iteration:	681	loss:	tensor(1.4938)
#
# iteration:	682	loss:	tensor(1.4970)
#
# iteration:	683	loss:	tensor(1.4876)
#
# iteration:	684	loss:	tensor(1.5209)
#
# iteration:	685	loss:	tensor(1.4852)
#
# iteration:	686	loss:	tensor(1.4976)
#
# iteration:	687	loss:	tensor(1.4825)
#
# iteration:	688	loss:	tensor(1.4980)
#
# iteration:	689	loss:	tensor(1.5002)
#
# iteration:	690	loss:	tensor(1.5062)
#
# iteration:	691	loss:	tensor(1.4979)
#
# iteration:	692	loss:	tensor(1.4845)
#
# iteration:	693	loss:	tensor(1.4917)
#
# iteration:	694	loss:	tensor(1.5147)
#
# iteration:	695	loss:	tensor(1.5158)
#
# iteration:	696	loss:	tensor(1.5316)
#
# iteration:	697	loss:	tensor(1.5284)
#
# iteration:	698	loss:	tensor(1.5957)
#
# iteration:	699	loss:	tensor(1.5223)
#
# iteration:	700	loss:	tensor(1.5047)
#
# iteration:	701	loss:	tensor(1.5117)
#
# iteration:	702	loss:	tensor(1.5165)
#
# iteration:	703	loss:	tensor(1.5140)
#
# iteration:	704	loss:	tensor(1.4986)
#
# iteration:	705	loss:	tensor(1.4914)
#
# iteration:	706	loss:	tensor(1.5027)
#
# iteration:	707	loss:	tensor(1.5055)
#
# iteration:	708	loss:	tensor(1.5199)
#
# iteration:	709	loss:	tensor(1.4979)
#
# iteration:	710	loss:	tensor(1.4970)
#
# iteration:	711	loss:	tensor(1.4874)
#
# iteration:	712	loss:	tensor(1.4975)
#
# iteration:	713	loss:	tensor(1.4789)
#
# iteration:	714	loss:	tensor(1.4735)
#
# iteration:	715	loss:	tensor(1.4851)
#
# iteration:	716	loss:	tensor(1.5117)
#
# iteration:	717	loss:	tensor(1.4976)
#
# iteration:	718	loss:	tensor(1.4847)
#
# iteration:	719	loss:	tensor(1.5398)
#
# iteration:	720	loss:	tensor(1.4828)
#
# iteration:	721	loss:	tensor(1.4897)
#
# iteration:	722	loss:	tensor(1.4872)
#
# iteration:	723	loss:	tensor(1.5222)
#
# iteration:	724	loss:	tensor(1.4959)
#
# iteration:	725	loss:	tensor(1.4915)
#
# iteration:	726	loss:	tensor(1.4854)
#
# iteration:	727	loss:	tensor(1.5165)
#
# iteration:	728	loss:	tensor(1.5065)
#
# iteration:	729	loss:	tensor(1.4934)
#
# iteration:	730	loss:	tensor(1.5010)
#
# iteration:	731	loss:	tensor(1.4994)
#
# iteration:	732	loss:	tensor(1.5086)
#
# iteration:	733	loss:	tensor(1.5026)
#
# iteration:	734	loss:	tensor(1.5018)
#
# iteration:	735	loss:	tensor(1.5041)
#
# iteration:	736	loss:	tensor(1.5054)
#
# iteration:	737	loss:	tensor(1.4942)
#
# iteration:	738	loss:	tensor(1.4981)
#
# iteration:	739	loss:	tensor(1.4867)
#
# iteration:	740	loss:	tensor(1.4995)
#
# iteration:	741	loss:	tensor(1.4840)
#
# iteration:	742	loss:	tensor(1.5178)
#
# iteration:	743	loss:	tensor(1.4809)
#
# iteration:	744	loss:	tensor(1.4798)
#
# iteration:	745	loss:	tensor(1.4996)
#
# iteration:	746	loss:	tensor(1.5050)
#
# iteration:	747	loss:	tensor(1.4712)
#
# iteration:	748	loss:	tensor(1.4785)
#
# iteration:	749	loss:	tensor(1.4853)
#
# iteration:	750	loss:	tensor(1.4857)
#
# iteration:	751	loss:	tensor(1.4802)
#
# iteration:	752	loss:	tensor(1.5100)
#
# iteration:	753	loss:	tensor(1.5047)
#
# iteration:	754	loss:	tensor(1.4928)
#
# iteration:	755	loss:	tensor(1.4985)
#
# iteration:	756	loss:	tensor(1.4884)
#
# iteration:	757	loss:	tensor(1.4839)
#
# iteration:	758	loss:	tensor(1.4722)
#
# iteration:	759	loss:	tensor(1.4767)
#
# iteration:	760	loss:	tensor(1.4673)
#
# iteration:	761	loss:	tensor(1.4823)
#
# iteration:	762	loss:	tensor(1.4563)
#
# iteration:	763	loss:	tensor(1.4674)
#
# iteration:	764	loss:	tensor(1.4788)
#
# iteration:	765	loss:	tensor(1.5240)
#
# iteration:	766	loss:	tensor(1.4718)
#
# iteration:	767	loss:	tensor(1.5027)
#
# iteration:	768	loss:	tensor(1.4812)
#
# iteration:	769	loss:	tensor(1.4765)
#
# iteration:	770	loss:	tensor(1.5274)
#
# iteration:	771	loss:	tensor(1.4893)
#
# iteration:	772	loss:	tensor(1.4986)
#
# iteration:	773	loss:	tensor(1.5191)
#
# iteration:	774	loss:	tensor(1.4903)
#
# iteration:	775	loss:	tensor(1.5010)
#
# iteration:	776	loss:	tensor(1.4913)
#
# iteration:	777	loss:	tensor(1.5053)
#
# iteration:	778	loss:	tensor(1.4868)
#
# iteration:	779	loss:	tensor(1.4986)
#
# iteration:	780	loss:	tensor(1.4922)
#
# iteration:	781	loss:	tensor(1.5175)
#
# iteration:	782	loss:	tensor(1.4705)
#
# iteration:	783	loss:	tensor(1.4722)
# iteration:	784	loss:	tensor(1.4686)
#
# iteration:	785	loss:	tensor(1.5007)
#
# iteration:	786	loss:	tensor(1.4823)
#
# iteration:	787	loss:	tensor(1.5036)
#
# iteration:	788	loss:	tensor(1.4801)
#
# iteration:	789	loss:	tensor(1.4634)
#
# iteration:	790	loss:	tensor(1.4728)
#
# iteration:	791	loss:	tensor(1.4653)
#
# iteration:	792	loss:	tensor(1.4726)
#
# iteration:	793	loss:	tensor(1.4671)
#
# iteration:	794	loss:	tensor(1.4810)
#
# iteration:	795	loss:	tensor(1.5088)
#
# iteration:	796	loss:	tensor(1.5032)
#
# iteration:	797	loss:	tensor(1.5199)
#
# iteration:	798	loss:	tensor(1.4773)
#
# iteration:	799	loss:	tensor(1.4834)
#
# iteration:	800	loss:	tensor(1.4667)
#
# iteration:	801	loss:	tensor(1.4642)
#
# iteration:	802	loss:	tensor(1.4817)
#
# iteration:	803	loss:	tensor(1.4538)
#
# iteration:	804	loss:	tensor(1.4536)
#
# iteration:	805	loss:	tensor(1.4580)
#
# iteration:	806	loss:	tensor(1.4711)
#
# iteration:	807	loss:	tensor(1.4689)
#
# iteration:	808	loss:	tensor(1.4807)
#
# iteration:	809	loss:	tensor(1.4908)
#
# iteration:	810	loss:	tensor(1.4778)
#
# iteration:	811	loss:	tensor(1.4908)
#
# iteration:	812	loss:	tensor(1.4932)
#
# iteration:	813	loss:	tensor(1.4981)
#
# iteration:	814	loss:	tensor(1.4844)
#
# iteration:	815	loss:	tensor(1.4930)
#
# iteration:	816	loss:	tensor(1.4932)
#
# iteration:	817	loss:	tensor(1.4892)
#
# iteration:	818	loss:	tensor(1.4962)
#
# iteration:	819	loss:	tensor(1.5597)
#
# iteration:	820	loss:	tensor(1.4639)
#
# iteration:	821	loss:	tensor(1.4648)
#
# iteration:	822	loss:	tensor(1.4759)
#
# iteration:	823	loss:	tensor(1.4680)
#
# iteration:	824	loss:	tensor(1.4835)
#
# iteration:	825	loss:	tensor(1.4683)
#
# iteration:	826	loss:	tensor(1.4906)
#
# iteration:	827	loss:	tensor(1.4783)
#
# iteration:	828	loss:	tensor(1.4905)
#
# iteration:	829	loss:	tensor(1.5082)
#
# iteration:	830	loss:	tensor(1.5223)
#
# iteration:	831	loss:	tensor(1.4672)
#
# iteration:	832	loss:	tensor(1.4730)
#
# iteration:	833	loss:	tensor(1.4639)
#
# iteration:	834	loss:	tensor(1.4893)
#
# iteration:	835	loss:	tensor(1.4653)
#
# iteration:	836	loss:	tensor(1.4618)
#
# iteration:	837	loss:	tensor(1.4660)
#
# iteration:	838	loss:	tensor(1.4664)
#
# iteration:	839	loss:	tensor(1.4755)
#
# iteration:	840	loss:	tensor(1.4920)
#
# iteration:	841	loss:	tensor(1.4580)
#
# iteration:	842	loss:	tensor(1.4515)
#
# iteration:	843	loss:	tensor(1.4648)
#
# iteration:	844	loss:	tensor(1.4592)
#
# iteration:	845	loss:	tensor(1.4973)
#
# iteration:	846	loss:	tensor(1.4764)
#
# iteration:	847	loss:	tensor(1.5773)
#
# iteration:	848	loss:	tensor(1.4699)
#
# iteration:	849	loss:	tensor(1.4711)
#
# iteration:	850	loss:	tensor(1.4786)
#
# iteration:	851	loss:	tensor(1.4689)
#
# iteration:	852	loss:	tensor(1.4708)
#
# iteration:	853	loss:	tensor(1.4977)
#
# iteration:	854	loss:	tensor(1.4660)
#
# iteration:	855	loss:	tensor(1.4694)
#
# iteration:	856	loss:	tensor(1.4685)
#
# iteration:	857	loss:	tensor(1.5151)
#
# iteration:	858	loss:	tensor(1.4766)
#
# iteration:	859	loss:	tensor(1.4705)
#
# iteration:	860	loss:	tensor(1.4829)
#
# iteration:	861	loss:	tensor(1.4592)
#
# iteration:	862	loss:	tensor(1.4605)
#
# iteration:	863	loss:	tensor(1.4590)
#
# iteration:	864	loss:	tensor(1.4802)
#
# iteration:	865	loss:	tensor(1.4556)
#
# iteration:	866	loss:	tensor(1.4717)
#
# iteration:	867	loss:	tensor(1.4508)
#
# iteration:	868	loss:	tensor(1.4994)
#
# iteration:	869	loss:	tensor(1.4648)
#
# iteration:	870	loss:	tensor(1.4606)
#
# iteration:	871	loss:	tensor(1.4712)
#
# iteration:	872	loss:	tensor(1.4781)
#
# iteration:	873	loss:	tensor(1.4728)
#
# iteration:	874	loss:	tensor(1.4668)
#
# iteration:	875	loss:	tensor(1.4770)
#
# iteration:	876	loss:	tensor(1.4668)
#
# iteration:	877	loss:	tensor(1.4661)
#
# iteration:	878	loss:	tensor(1.4574)
#
# iteration:	879	loss:	tensor(1.4489)
#
# iteration:	880	loss:	tensor(1.4437)
#
# iteration:	881	loss:	tensor(1.4636)
#
# iteration:	882	loss:	tensor(1.4505)
#
# iteration:	883	loss:	tensor(1.4646)
#
# iteration:	884	loss:	tensor(1.4805)
#
# iteration:	885	loss:	tensor(1.4725)
#
# iteration:	886	loss:	tensor(1.4713)
#
# iteration:	887	loss:	tensor(1.4945)
#
# iteration:	888	loss:	tensor(1.4901)
#
# iteration:	889	loss:	tensor(1.5028)
#
# iteration:	890	loss:	tensor(1.4668)
#
# iteration:	891	loss:	tensor(1.4894)
#
# iteration:	892	loss:	tensor(1.4645)
#
# iteration:	893	loss:	tensor(1.4547)
#
# iteration:	894	loss:	tensor(1.4579)
#
# iteration:	895	loss:	tensor(1.4883)
#
# iteration:	896	loss:	tensor(1.4613)
#
# iteration:	897	loss:	tensor(1.5175)
#
# iteration:	898	loss:	tensor(1.4497)
#
# iteration:	899	loss:	tensor(1.4820)
#
# iteration:	900	loss:	tensor(1.4629)
#
# iteration:	901	loss:	tensor(1.5399)
#
# iteration:	902	loss:	tensor(1.4484)
#
# iteration:	903	loss:	tensor(1.4460)
#
# iteration:	904	loss:	tensor(1.4620)
#
# iteration:	905	loss:	tensor(1.4422)
#
# iteration:	906	loss:	tensor(1.4501)
#
# iteration:	907	loss:	tensor(1.4496)
#
# iteration:	908	loss:	tensor(1.4573)
#
# iteration:	909	loss:	tensor(1.4656)
#
# iteration:	910	loss:	tensor(1.4927)
#
# iteration:	911	loss:	tensor(1.4973)
#
# iteration:	912	loss:	tensor(1.5041)
#
# iteration:	913	loss:	tensor(1.5212)
#
# iteration:	914	loss:	tensor(1.4710)
#
# iteration:	915	loss:	tensor(1.4727)
#
# iteration:	916	loss:	tensor(1.4921)
#
# iteration:	917	loss:	tensor(1.4534)
#
# iteration:	918	loss:	tensor(1.4607)
#
# iteration:	919	loss:	tensor(1.4448)
#
# iteration:	920	loss:	tensor(1.4540)
#
# iteration:	921	loss:	tensor(1.4662)
#
# iteration:	922	loss:	tensor(1.5178)
#
# iteration:	923	loss:	tensor(1.4632)
#
# iteration:	924	loss:	tensor(1.4458)
#
# iteration:	925	loss:	tensor(1.4523)
#
# iteration:	926	loss:	tensor(1.4467)
#
# iteration:	927	loss:	tensor(1.4577)
#
# iteration:	928	loss:	tensor(1.4776)
#
# iteration:	929	loss:	tensor(1.4901)
#
# iteration:	930	loss:	tensor(1.5081)
#
# iteration:	931	loss:	tensor(1.4535)
#
# iteration:	932	loss:	tensor(1.4339)
#
# iteration:	933	loss:	tensor(1.4521)
#
# iteration:	934	loss:	tensor(1.4424)
#
# iteration:	935	loss:	tensor(1.4556)
#
# iteration:	936	loss:	tensor(1.4568)
#
# iteration:	937	loss:	tensor(1.5100)
#
# iteration:	938	loss:	tensor(1.4829)
#
# iteration:	939	loss:	tensor(1.5315)
#
# iteration:	940	loss:	tensor(1.4646)
#
# iteration:	941	loss:	tensor(1.4493)
#
# iteration:	942	loss:	tensor(1.4400)
#
# iteration:	943	loss:	tensor(1.4431)
#
# iteration:	944	loss:	tensor(1.4610)
#
# iteration:	945	loss:	tensor(1.4983)
#
# iteration:	946	loss:	tensor(1.4515)
#
# iteration:	947	loss:	tensor(1.4596)
#
# iteration:	948	loss:	tensor(1.4660)
#
# iteration:	949	loss:	tensor(1.4522)
#
# iteration:	950	loss:	tensor(1.4493)
#
# iteration:	951	loss:	tensor(1.4473)
#
# iteration:	952	loss:	tensor(1.4544)
#
# iteration:	953	loss:	tensor(1.4627)
#
# iteration:	954	loss:	tensor(1.4863)
#
# iteration:	955	loss:	tensor(1.4466)
#
# iteration:	956	loss:	tensor(1.4567)
#
# iteration:	957	loss:	tensor(1.4774)
#
# iteration:	958	loss:	tensor(1.4714)
#
# iteration:	959	loss:	tensor(1.4447)
#
# iteration:	960	loss:	tensor(1.4520)
#
# iteration:	961	loss:	tensor(1.4858)
#
# iteration:	962	loss:	tensor(1.4613)
#
# iteration:	963	loss:	tensor(1.4428)
#
# iteration:	964	loss:	tensor(1.4685)
#
# iteration:	965	loss:	tensor(1.4884)
#
# iteration:	966	loss:	tensor(1.4938)
#
# iteration:	967	loss:	tensor(1.4952)
#
# iteration:	968	loss:	tensor(1.4951)
#
# iteration:	969	loss:	tensor(1.4668)
#
# iteration:	970	loss:	tensor(1.5010)
#
# iteration:	971	loss:	tensor(1.4875)
#
# iteration:	972	loss:	tensor(1.4750)
#
# iteration:	973	loss:	tensor(1.4448)
#
# iteration:	974	loss:	tensor(1.4625)
#
# iteration:	975	loss:	tensor(1.4577)
#
# iteration:	976	loss:	tensor(1.4645)
#
# iteration:	977	loss:	tensor(1.4548)
#
# iteration:	978	loss:	tensor(1.4573)
#
# iteration:	979	loss:	tensor(1.4477)
#
# iteration:	980	loss:	tensor(1.4452)
#
# iteration:	981	loss:	tensor(1.4381)
#
# iteration:	982	loss:	tensor(1.4331)
#
# iteration:	983	loss:	tensor(1.4420)
#
# iteration:	984	loss:	tensor(1.4658)
#
# iteration:	985	loss:	tensor(1.4468)
#
# iteration:	986	loss:	tensor(1.4537)
#
# iteration:	987	loss:	tensor(1.4644)
#
# iteration:	988	loss:	tensor(1.4471)
#
# iteration:	989	loss:	tensor(1.4361)
#
# iteration:	990	loss:	tensor(1.4391)
#
# iteration:	991	loss:	tensor(1.4439)
#
# iteration:	992	loss:	tensor(1.4292)
#
# iteration:	993	loss:	tensor(1.4354)
#
# iteration:	994	loss:	tensor(1.4379)
#
# iteration:	995	loss:	tensor(1.4794)
#
# iteration:	996	loss:	tensor(1.4514)
#
# iteration:	997	loss:	tensor(1.4370)
#
# iteration:	998	loss:	tensor(1.4627)
#
# iteration:	999	loss:	tensor(1.4505)
#
# iteration:	1000	loss:	tensor(1.4844)
#
# iteration:	1001	loss:	tensor(1.4569)
#
# iteration:	1002	loss:	tensor(1.4785)
#
# iteration:	1003	loss:	tensor(1.4710)
#
# iteration:	1004	loss:	tensor(1.4816)
#
# iteration:	1005	loss:	tensor(1.4627)
#
# iteration:	1006	loss:	tensor(1.4628)
#
# iteration:	1007	loss:	tensor(1.4820)
#
# iteration:	1008	loss:	tensor(1.4744)
#
# iteration:	1009	loss:	tensor(1.4826)
#
# iteration:	1010	loss:	tensor(1.4965)
#
# iteration:	1011	loss:	tensor(1.4450)
#
# iteration:	1012	loss:	tensor(1.4394)
#
# iteration:	1013	loss:	tensor(1.4421)
#
# iteration:	1014	loss:	tensor(1.4747)
#
# iteration:	1015	loss:	tensor(1.4359)
#
# iteration:	1016	loss:	tensor(1.4537)
#
# iteration:	1017	loss:	tensor(1.4421)
#
# iteration:	1018	loss:	tensor(1.4372)
#
# iteration:	1019	loss:	tensor(1.4447)
#
# iteration:	1020	loss:	tensor(1.4404)
#
# iteration:	1021	loss:	tensor(1.4556)
#
# iteration:	1022	loss:	tensor(1.5026)
#
# iteration:	1023	loss:	tensor(1.4523)
#
# iteration:	1024	loss:	tensor(1.4309)
#
# iteration:	1025	loss:	tensor(1.4466)
#
# iteration:	1026	loss:	tensor(1.4678)
#
# iteration:	1027	loss:	tensor(1.4566)
#
# iteration:	1028	loss:	tensor(1.4601)
#
# iteration:	1029	loss:	tensor(1.4680)
#
# iteration:	1030	loss:	tensor(1.4643)
#
# iteration:	1031	loss:	tensor(1.4610)
#
# iteration:	1032	loss:	tensor(1.4617)
#
# iteration:	1033	loss:	tensor(1.4584)
#
# iteration:	1034	loss:	tensor(1.4426)
#
# iteration:	1035	loss:	tensor(1.4526)
#
# iteration:	1036	loss:	tensor(1.4510)
#
# iteration:	1037	loss:	tensor(1.4402)
#
# iteration:	1038	loss:	tensor(1.4315)
#
# iteration:	1039	loss:	tensor(1.4524)
#
# iteration:	1040	loss:	tensor(1.4460)
#
# iteration:	1041	loss:	tensor(1.4492)
#
# iteration:	1042	loss:	tensor(1.4617)
#
# iteration:	1043	loss:	tensor(1.4831)
#
# iteration:	1044	loss:	tensor(1.4354)
#
# iteration:	1045	loss:	tensor(1.4435)
#
# iteration:	1046	loss:	tensor(1.4922)
#
# iteration:	1047	loss:	tensor(1.5256)
# iteration:	1048	loss:	tensor(1.4322)
#
# iteration:	1049	loss:	tensor(1.4283)
#
# iteration:	1050	loss:	tensor(1.4233)
#
# iteration:	1051	loss:	tensor(1.4268)
#
# iteration:	1052	loss:	tensor(1.4326)
#
# iteration:	1053	loss:	tensor(1.4271)
#
# iteration:	1054	loss:	tensor(1.4471)
#
# iteration:	1055	loss:	tensor(1.4240)
#
# iteration:	1056	loss:	tensor(1.4317)
#
# iteration:	1057	loss:	tensor(1.4429)
#
# iteration:	1058	loss:	tensor(1.4683)
#
# iteration:	1059	loss:	tensor(1.4429)
#
# iteration:	1060	loss:	tensor(1.4705)
#
# iteration:	1061	loss:	tensor(1.4488)
#
# iteration:	1062	loss:	tensor(1.4626)
#
# iteration:	1063	loss:	tensor(1.4553)
#
# iteration:	1064	loss:	tensor(1.4574)
#
# iteration:	1065	loss:	tensor(1.4712)
#
# iteration:	1066	loss:	tensor(1.4745)
#
# iteration:	1067	loss:	tensor(1.4704)
#
# iteration:	1068	loss:	tensor(1.4697)
#
# iteration:	1069	loss:	tensor(1.5065)
#
# iteration:	1070	loss:	tensor(1.4751)
#
# iteration:	1071	loss:	tensor(1.4901)
#
# iteration:	1072	loss:	tensor(1.4468)
#
# iteration:	1073	loss:	tensor(1.4306)
#
# iteration:	1074	loss:	tensor(1.4261)
#
# iteration:	1075	loss:	tensor(1.4383)
#
# iteration:	1076	loss:	tensor(1.4667)
#
# iteration:	1077	loss:	tensor(1.4559)
#
# iteration:	1078	loss:	tensor(1.4180)
#
# iteration:	1079	loss:	tensor(1.4146)
#
# iteration:	1080	loss:	tensor(1.4138)
#
# iteration:	1081	loss:	tensor(1.4150)
#
# iteration:	1082	loss:	tensor(1.4160)
#
# iteration:	1083	loss:	tensor(1.4260)
#
# iteration:	1084	loss:	tensor(1.4458)
#
# iteration:	1085	loss:	tensor(1.4932)
#
# iteration:	1086	loss:	tensor(1.4419)
#
# iteration:	1087	loss:	tensor(1.4336)
#
# iteration:	1088	loss:	tensor(1.4459)
#
# iteration:	1089	loss:	tensor(1.4594)
#
# iteration:	1090	loss:	tensor(1.4775)
#
# iteration:	1091	loss:	tensor(1.4510)
#
# iteration:	1092	loss:	tensor(1.4397)
#
# iteration:	1093	loss:	tensor(1.4277)
#
# iteration:	1094	loss:	tensor(1.4313)
#
# iteration:	1095	loss:	tensor(1.4474)
#
# iteration:	1096	loss:	tensor(1.4716)
#
# iteration:	1097	loss:	tensor(1.4414)
#
# iteration:	1098	loss:	tensor(1.4183)
#
# iteration:	1099	loss:	tensor(1.4164)
#
# iteration:	1100	loss:	tensor(1.4231)
#
# iteration:	1101	loss:	tensor(1.4264)
#
# iteration:	1102	loss:	tensor(1.4593)
#
# iteration:	1103	loss:	tensor(1.4936)
#
# iteration:	1104	loss:	tensor(1.4953)
#
# iteration:	1105	loss:	tensor(1.4227)
#
# iteration:	1106	loss:	tensor(1.4260)
#
# iteration:	1107	loss:	tensor(1.4536)
#
# iteration:	1108	loss:	tensor(1.5038)
#
# iteration:	1109	loss:	tensor(1.4320)
#
# iteration:	1110	loss:	tensor(1.4349)
#
# iteration:	1111	loss:	tensor(1.4514)
#
# iteration:	1112	loss:	tensor(1.4464)
#
# iteration:	1113	loss:	tensor(1.4376)
#
# iteration:	1114	loss:	tensor(1.4365)
#
# iteration:	1115	loss:	tensor(1.4428)
#
# iteration:	1116	loss:	tensor(1.4418)
#
# iteration:	1117	loss:	tensor(1.4453)
#
# iteration:	1118	loss:	tensor(1.4653)
#
# iteration:	1119	loss:	tensor(1.4430)
#
# iteration:	1120	loss:	tensor(1.4532)
#
# iteration:	1121	loss:	tensor(1.4335)
#
# iteration:	1122	loss:	tensor(1.4315)
#
# iteration:	1123	loss:	tensor(1.4480)
#
# iteration:	1124	loss:	tensor(1.4391)
#
# iteration:	1125	loss:	tensor(1.4321)
#
# iteration:	1126	loss:	tensor(1.4351)
#
# iteration:	1127	loss:	tensor(1.4216)
#
# iteration:	1128	loss:	tensor(1.4316)
#
# iteration:	1129	loss:	tensor(1.4319)
#
# iteration:	1130	loss:	tensor(1.4612)
#
# iteration:	1131	loss:	tensor(1.4241)
#
# iteration:	1132	loss:	tensor(1.4430)
#
# iteration:	1133	loss:	tensor(1.4294)
#
# iteration:	1134	loss:	tensor(1.4384)
#
# iteration:	1135	loss:	tensor(1.4441)
#
# iteration:	1136	loss:	tensor(1.4700)
#
# iteration:	1137	loss:	tensor(1.4350)
#
# iteration:	1138	loss:	tensor(1.4268)
#
# iteration:	1139	loss:	tensor(1.4373)
#
# iteration:	1140	loss:	tensor(1.4266)
#
# iteration:	1141	loss:	tensor(1.4384)
#
# iteration:	1142	loss:	tensor(1.4564)
#
# iteration:	1143	loss:	tensor(1.4484)
#
# iteration:	1144	loss:	tensor(1.4388)
#
# iteration:	1145	loss:	tensor(1.4162)
#
# iteration:	1146	loss:	tensor(1.4158)
#
# iteration:	1147	loss:	tensor(1.4253)
#
# iteration:	1148	loss:	tensor(1.4339)
#
# iteration:	1149	loss:	tensor(1.4899)
#
# iteration:	1150	loss:	tensor(1.5081)
#
# iteration:	1151	loss:	tensor(1.4369)
#
# iteration:	1152	loss:	tensor(1.4650)
#
# iteration:	1153	loss:	tensor(1.4381)
#
# iteration:	1154	loss:	tensor(1.4590)
#
# iteration:	1155	loss:	tensor(1.4579)
#
# iteration:	1156	loss:	tensor(1.5477)
#
# iteration:	1157	loss:	tensor(1.4328)
#
# iteration:	1158	loss:	tensor(1.4251)
#
# iteration:	1159	loss:	tensor(1.4209)
#
# iteration:	1160	loss:	tensor(1.4125)
#
# iteration:	1161	loss:	tensor(1.4212)
#
# iteration:	1162	loss:	tensor(1.4164)
#
# iteration:	1163	loss:	tensor(1.4429)
#
# iteration:	1164	loss:	tensor(1.4268)
#
# iteration:	1165	loss:	tensor(1.4506)
#
# iteration:	1166	loss:	tensor(1.4253)
#
# iteration:	1167	loss:	tensor(1.4295)
#
# iteration:	1168	loss:	tensor(1.4592)
#
# iteration:	1169	loss:	tensor(1.4870)
#
# iteration:	1170	loss:	tensor(1.4696)
#
# iteration:	1171	loss:	tensor(1.4267)
#
# iteration:	1172	loss:	tensor(1.4447)
#
# iteration:	1173	loss:	tensor(1.4731)
#
# iteration:	1174	loss:	tensor(1.4547)
#
# iteration:	1175	loss:	tensor(1.4329)
#
# iteration:	1176	loss:	tensor(1.4496)
#
# iteration:	1177	loss:	tensor(1.4622)
#
# iteration:	1178	loss:	tensor(1.4551)
#
# iteration:	1179	loss:	tensor(1.4562)
#
# iteration:	1180	loss:	tensor(1.4751)
#
# iteration:	1181	loss:	tensor(1.4471)
#
# iteration:	1182	loss:	tensor(1.4307)
#
# iteration:	1183	loss:	tensor(1.4185)
#
# iteration:	1184	loss:	tensor(1.4380)
#
# iteration:	1185	loss:	tensor(1.4133)
#
# iteration:	1186	loss:	tensor(1.4161)
#
# iteration:	1187	loss:	tensor(1.4326)
#
# iteration:	1188	loss:	tensor(1.4705)
#
# iteration:	1189	loss:	tensor(1.4473)
#
# iteration:	1190	loss:	tensor(1.5069)
#
# iteration:	1191	loss:	tensor(1.4372)
#
# iteration:	1192	loss:	tensor(1.4302)
#
# iteration:	1193	loss:	tensor(1.4378)
#
# iteration:	1194	loss:	tensor(1.4333)
#
# iteration:	1195	loss:	tensor(1.4369)
#
# iteration:	1196	loss:	tensor(1.4294)
#
# iteration:	1197	loss:	tensor(1.4396)
#
# iteration:	1198	loss:	tensor(1.4222)
#
# iteration:	1199	loss:	tensor(1.4220)
#
# iteration:	1200	loss:	tensor(1.4128)
#
# iteration:	1201	loss:	tensor(1.4206)
#
# iteration:	1202	loss:	tensor(1.4224)
#
# iteration:	1203	loss:	tensor(1.4536)
#
# iteration:	1204	loss:	tensor(1.4412)
#
# iteration:	1205	loss:	tensor(1.5184)
#
# iteration:	1206	loss:	tensor(1.4282)
#
# iteration:	1207	loss:	tensor(1.4057)
#
# iteration:	1208	loss:	tensor(1.4055)
#
# iteration:	1209	loss:	tensor(1.4043)
#
# iteration:	1210	loss:	tensor(1.4181)
#
# iteration:	1211	loss:	tensor(1.4294)
#
# iteration:	1212	loss:	tensor(1.4991)
#
# iteration:	1213	loss:	tensor(1.5178)
#
# iteration:	1214	loss:	tensor(1.4301)
#
# iteration:	1215	loss:	tensor(1.4207)
#
# iteration:	1216	loss:	tensor(1.4377)
#
# iteration:	1217	loss:	tensor(1.4723)
#
# iteration:	1218	loss:	tensor(1.4711)
#
# iteration:	1219	loss:	tensor(1.4345)
#
# iteration:	1220	loss:	tensor(1.4746)
#
# iteration:	1221	loss:	tensor(1.4456)
#
# iteration:	1222	loss:	tensor(1.4922)
#
# iteration:	1223	loss:	tensor(1.4352)
#
# iteration:	1224	loss:	tensor(1.4260)
#
# iteration:	1225	loss:	tensor(1.4209)
#
# iteration:	1226	loss:	tensor(1.4241)
#
# iteration:	1227	loss:	tensor(1.4391)
#
# iteration:	1228	loss:	tensor(1.4459)
#
# iteration:	1229	loss:	tensor(1.4205)
#
# iteration:	1230	loss:	tensor(1.4360)
#
# iteration:	1231	loss:	tensor(1.4580)
#
# iteration:	1232	loss:	tensor(1.4724)
#
# iteration:	1233	loss:	tensor(1.4132)
#
# iteration:	1234	loss:	tensor(1.4115)
#
# iteration:	1235	loss:	tensor(1.4063)
#
# iteration:	1236	loss:	tensor(1.4112)
#
# iteration:	1237	loss:	tensor(1.4078)
#
# iteration:	1238	loss:	tensor(1.4159)
#
# iteration:	1239	loss:	tensor(1.4282)
#
# iteration:	1240	loss:	tensor(1.4639)
#
# iteration:	1241	loss:	tensor(1.4465)
#
# iteration:	1242	loss:	tensor(1.4356)
#
# iteration:	1243	loss:	tensor(1.4374)
#
# iteration:	1244	loss:	tensor(1.4593)
#
# iteration:	1245	loss:	tensor(1.4728)
#
# iteration:	1246	loss:	tensor(1.4704)
#
# iteration:	1247	loss:	tensor(1.4315)
#
# iteration:	1248	loss:	tensor(1.4441)
#
# iteration:	1249	loss:	tensor(1.4532)
#
# iteration:	1250	loss:	tensor(1.4354)
#
# iteration:	1251	loss:	tensor(1.4318)
#
# iteration:	1252	loss:	tensor(1.4297)
#
# iteration:	1253	loss:	tensor(1.4366)
#
# iteration:	1254	loss:	tensor(1.4162)
#
# iteration:	1255	loss:	tensor(1.4307)
#
# iteration:	1256	loss:	tensor(1.4173)
#
# iteration:	1257	loss:	tensor(1.4106)
#
# iteration:	1258	loss:	tensor(1.4365)
#
# iteration:	1259	loss:	tensor(1.4178)
#
# iteration:	1260	loss:	tensor(1.4227)
#
# iteration:	1261	loss:	tensor(1.4086)
#
# iteration:	1262	loss:	tensor(1.4095)
#
# iteration:	1263	loss:	tensor(1.4176)
#
# iteration:	1264	loss:	tensor(1.4340)
#
# iteration:	1265	loss:	tensor(1.4448)
#
# iteration:	1266	loss:	tensor(1.4179)
# iteration:	1267	loss:	tensor(1.4094)
#
# iteration:	1268	loss:	tensor(1.4261)
#
# iteration:	1269	loss:	tensor(1.4519)
#
# iteration:	1270	loss:	tensor(1.5232)
#
# iteration:	1271	loss:	tensor(1.4575)
#
# iteration:	1272	loss:	tensor(1.4775)
#
# iteration:	1273	loss:	tensor(1.4446)
#
# iteration:	1274	loss:	tensor(1.4512)
#
# iteration:	1275	loss:	tensor(1.4320)
#
# iteration:	1276	loss:	tensor(1.4304)
#
# iteration:	1277	loss:	tensor(1.4441)
#
# iteration:	1278	loss:	tensor(1.4625)
#
# iteration:	1279	loss:	tensor(1.4432)
#
# iteration:	1280	loss:	tensor(1.4922)
#
# iteration:	1281	loss:	tensor(1.4281)
#
# iteration:	1282	loss:	tensor(1.4139)
#
# iteration:	1283	loss:	tensor(1.4195)
#
# iteration:	1284	loss:	tensor(1.4194)
#
# iteration:	1285	loss:	tensor(1.4332)
#
# iteration:	1286	loss:	tensor(1.4244)
#
# ...
#
# iteration:	9579	loss:	tensor(1.3130)
#
# iteration:	9580	loss:	tensor(1.3120)
#
# iteration:	9581	loss:	tensor(1.3137)
#
# iteration:	9582	loss:	tensor(1.3120)
#
# iteration:	9583	loss:	tensor(1.3140)
#
# iteration:	9584	loss:	tensor(1.3110)
#
# iteration:	9585	loss:	tensor(1.3133)
#
# iteration:	9586	loss:	tensor(1.3105)
#
# iteration:	9587	loss:	tensor(1.3150)
#
# iteration:	9588	loss:	tensor(1.3116)
#
# iteration:	9589	loss:	tensor(1.3141)
#
# iteration:	9590	loss:	tensor(1.3128)
#
# iteration:	9591	loss:	tensor(1.3144)
#
# iteration:	9592	loss:	tensor(1.3131)
#
# iteration:	9593	loss:	tensor(1.3138)
#
# iteration:	9594	loss:	tensor(1.3112)
#
# iteration:	9595	loss:	tensor(1.3121)
#
# iteration:	9596	loss:	tensor(1.3095)
#
# iteration:	9597	loss:	tensor(1.3127)
#
# iteration:	9598	loss:	tensor(1.3111)
#
# iteration:	9599	loss:	tensor(1.3131)
#
# iteration:	9600	loss:	tensor(1.3111)
#
# iteration:	9601	loss:	tensor(1.3121)
#
# iteration:	9602	loss:	tensor(1.3115)
#
# iteration:	9603	loss:	tensor(1.3130)
#
# iteration:	9604	loss:	tensor(1.3121)
#
# iteration:	9605	loss:	tensor(1.3145)
#
# iteration:	9606	loss:	tensor(1.3135)
#
# iteration:	9607	loss:	tensor(1.3194)
#
# iteration:	9608	loss:	tensor(1.3121)
#
# iteration:	9609	loss:	tensor(1.3139)
#
# iteration:	9610	loss:	tensor(1.3137)
#
# iteration:	9611	loss:	tensor(1.3216)
#
# iteration:	9612	loss:	tensor(1.3251)
#
# iteration:	9613	loss:	tensor(1.3565)
#
# iteration:	9614	loss:	tensor(1.3249)
#
# iteration:	9615	loss:	tensor(1.3198)
#
# iteration:	9616	loss:	tensor(1.3186)
#
# iteration:	9617	loss:	tensor(1.3236)
#
# iteration:	9618	loss:	tensor(1.3258)
#
# iteration:	9619	loss:	tensor(1.3537)
#
# iteration:	9620	loss:	tensor(1.3378)
#
# iteration:	9621	loss:	tensor(1.3429)
#
# iteration:	9622	loss:	tensor(1.3358)
#
# iteration:	9623	loss:	tensor(1.3944)
#
# iteration:	9624	loss:	tensor(1.3247)
#
# iteration:	9625	loss:	tensor(1.3146)
#
# iteration:	9626	loss:	tensor(1.3150)
#
# iteration:	9627	loss:	tensor(1.3111)
#
# iteration:	9628	loss:	tensor(1.3166)
#
# iteration:	9629	loss:	tensor(1.3162)
#
# iteration:	9630	loss:	tensor(1.3333)
#
# iteration:	9631	loss:	tensor(1.3298)
#
# iteration:	9632	loss:	tensor(1.3612)
#
# iteration:	9633	loss:	tensor(1.3149)
#
# iteration:	9634	loss:	tensor(1.3125)
#
# iteration:	9635	loss:	tensor(1.3105)
#
# iteration:	9636	loss:	tensor(1.3147)
#
# iteration:	9637	loss:	tensor(1.3116)
#
# iteration:	9638	loss:	tensor(1.3167)
#
# iteration:	9639	loss:	tensor(1.3122)
#
# iteration:	9640	loss:	tensor(1.3152)
#
# iteration:	9641	loss:	tensor(1.3130)
#
# iteration:	9642	loss:	tensor(1.3170)
#
# iteration:	9643	loss:	tensor(1.3245)
#
# iteration:	9644	loss:	tensor(1.3194)
#
# iteration:	9645	loss:	tensor(1.3406)
#
# iteration:	9646	loss:	tensor(1.3251)
#
# iteration:	9647	loss:	tensor(1.3574)
#
# iteration:	9648	loss:	tensor(1.3158)
#
# iteration:	9649	loss:	tensor(1.3168)
#
# iteration:	9650	loss:	tensor(1.3121)
#
# iteration:	9651	loss:	tensor(1.3158)
#
# iteration:	9652	loss:	tensor(1.3188)
#
# iteration:	9653	loss:	tensor(1.3368)
#
# iteration:	9654	loss:	tensor(1.3159)
# iteration:	9655	loss:	tensor(1.3208)
#
# iteration:	9656	loss:	tensor(1.3144)
#
# iteration:	9657	loss:	tensor(1.3194)
#
# iteration:	9658	loss:	tensor(1.3148)
#
# iteration:	9659	loss:	tensor(1.3226)
#
# iteration:	9660	loss:	tensor(1.3220)
#
# iteration:	9661	loss:	tensor(1.3413)
#
# iteration:	9662	loss:	tensor(1.3157)
#
# iteration:	9663	loss:	tensor(1.3161)
#
# iteration:	9664	loss:	tensor(1.3099)
#
# iteration:	9665	loss:	tensor(1.3106)
#
# iteration:	9666	loss:	tensor(1.3111)
#
# iteration:	9667	loss:	tensor(1.3129)
#
# iteration:	9668	loss:	tensor(1.3117)
#
# iteration:	9669	loss:	tensor(1.3128)
#
# iteration:	9670	loss:	tensor(1.3118)
#
# iteration:	9671	loss:	tensor(1.3129)
#
# iteration:	9672	loss:	tensor(1.3113)
#
# iteration:	9673	loss:	tensor(1.3125)
#
# iteration:	9674	loss:	tensor(1.3111)
#
# iteration:	9675	loss:	tensor(1.3131)
#
# iteration:	9676	loss:	tensor(1.3108)
#
# iteration:	9677	loss:	tensor(1.3128)
#
# iteration:	9678	loss:	tensor(1.3103)
#
# iteration:	9679	loss:	tensor(1.3111)
#
# iteration:	9680	loss:	tensor(1.3099)
#
# iteration:	9681	loss:	tensor(1.3131)
#
# iteration:	9682	loss:	tensor(1.3104)
#
# iteration:	9683	loss:	tensor(1.3136)
#
# iteration:	9684	loss:	tensor(1.3106)
#
# iteration:	9685	loss:	tensor(1.3146)
#
# iteration:	9686	loss:	tensor(1.3130)
#
# iteration:	9687	loss:	tensor(1.3184)
#
# iteration:	9688	loss:	tensor(1.3149)
#
# iteration:	9689	loss:	tensor(1.3226)
#
# iteration:	9690	loss:	tensor(1.3201)
#
# iteration:	9691	loss:	tensor(1.3344)
#
# iteration:	9692	loss:	tensor(1.3187)
#
# iteration:	9693	loss:	tensor(1.3296)
#
# iteration:	9694	loss:	tensor(1.3242)
#
# iteration:	9695	loss:	tensor(1.3466)
#
# iteration:	9696	loss:	tensor(1.3176)
#
# iteration:	9697	loss:	tensor(1.3146)
#
# iteration:	9698	loss:	tensor(1.3100)
#
# iteration:	9699	loss:	tensor(1.3114)
#
# iteration:	9700	loss:	tensor(1.3105)
#
# iteration:	9701	loss:	tensor(1.3121)
#
# iteration:	9702	loss:	tensor(1.3108)
#
# iteration:	9703	loss:	tensor(1.3110)
#
# iteration:	9704	loss:	tensor(1.3109)
#
# iteration:	9705	loss:	tensor(1.3112)
#
# iteration:	9706	loss:	tensor(1.3115)
#
# iteration:	9707	loss:	tensor(1.3133)
#
# iteration:	9708	loss:	tensor(1.3126)
#
# iteration:	9709	loss:	tensor(1.3134)
#
# iteration:	9710	loss:	tensor(1.3127)
#
# iteration:	9711	loss:	tensor(1.3133)
#
# iteration:	9712	loss:	tensor(1.3125)
#
# iteration:	9713	loss:	tensor(1.3128)
#
# iteration:	9714	loss:	tensor(1.3121)
#
# iteration:	9715	loss:	tensor(1.3132)
#
# iteration:	9716	loss:	tensor(1.3129)
#
# iteration:	9717	loss:	tensor(1.3155)
#
# iteration:	9718	loss:	tensor(1.3180)
#
# iteration:	9719	loss:	tensor(1.3148)
#
# iteration:	9720	loss:	tensor(1.3247)
#
# iteration:	9721	loss:	tensor(1.3193)
#
# iteration:	9722	loss:	tensor(1.3366)
#
# iteration:	9723	loss:	tensor(1.3200)
#
# iteration:	9724	loss:	tensor(1.3323)
#
# iteration:	9725	loss:	tensor(1.3221)
#
# iteration:	9726	loss:	tensor(1.3351)
#
# iteration:	9727	loss:	tensor(1.3188)
#
# iteration:	9728	loss:	tensor(1.3240)
#
# iteration:	9729	loss:	tensor(1.3154)
#
# iteration:	9730	loss:	tensor(1.3207)
#
# iteration:	9731	loss:	tensor(1.3140)
#
# iteration:	9732	loss:	tensor(1.3182)
#
# iteration:	9733	loss:	tensor(1.3183)
#
# iteration:	9734	loss:	tensor(1.3262)
#
# iteration:	9735	loss:	tensor(1.3224)
#
# iteration:	9736	loss:	tensor(1.3624)
#
# iteration:	9737	loss:	tensor(1.3324)
#
# iteration:	9738	loss:	tensor(1.3393)
#
# iteration:	9739	loss:	tensor(1.3253)
#
# iteration:	9740	loss:	tensor(1.3495)
#
# iteration:	9741	loss:	tensor(1.3314)
#
# iteration:	9742	loss:	tensor(1.3355)
#
# iteration:	9743	loss:	tensor(1.3209)
#
# iteration:	9744	loss:	tensor(1.3236)
#
# iteration:	9745	loss:	tensor(1.3120)
#
# iteration:	9746	loss:	tensor(1.3115)
#
# iteration:	9747	loss:	tensor(1.3110)
#
# iteration:	9748	loss:	tensor(1.3120)
#
# iteration:	9749	loss:	tensor(1.3097)
#
# iteration:	9750	loss:	tensor(1.3110)
#
# iteration:	9751	loss:	tensor(1.3106)
#
# iteration:	9752	loss:	tensor(1.3122)
#
# iteration:	9753	loss:	tensor(1.3130)
#
# iteration:	9754	loss:	tensor(1.3173)
#
# iteration:	9755	loss:	tensor(1.3158)
#
# iteration:	9756	loss:	tensor(1.3225)
#
# iteration:	9757	loss:	tensor(1.3266)
#
# iteration:	9758	loss:	tensor(1.3683)
#
# iteration:	9759	loss:	tensor(1.3163)
#
# iteration:	9760	loss:	tensor(1.3112)
#
# iteration:	9761	loss:	tensor(1.3095)
#
# iteration:	9762	loss:	tensor(1.3119)
#
# iteration:	9763	loss:	tensor(1.3131)
#
# iteration:	9764	loss:	tensor(1.3180)
#
# iteration:	9765	loss:	tensor(1.3103)
#
# iteration:	9766	loss:	tensor(1.3144)
#
# iteration:	9767	loss:	tensor(1.3118)
#
# iteration:	9768	loss:	tensor(1.3175)
#
# iteration:	9769	loss:	tensor(1.3110)
#
# iteration:	9770	loss:	tensor(1.3143)
#
# iteration:	9771	loss:	tensor(1.3101)
#
# iteration:	9772	loss:	tensor(1.3148)
#
# iteration:	9773	loss:	tensor(1.3103)
#
# iteration:	9774	loss:	tensor(1.3137)
#
# iteration:	9775	loss:	tensor(1.3104)
#
# iteration:	9776	loss:	tensor(1.3159)
#
# iteration:	9777	loss:	tensor(1.3108)
#
# iteration:	9778	loss:	tensor(1.3153)
#
# iteration:	9779	loss:	tensor(1.3121)
#
# iteration:	9780	loss:	tensor(1.3177)
#
# iteration:	9781	loss:	tensor(1.3215)
#
# iteration:	9782	loss:	tensor(1.3187)
#
# iteration:	9783	loss:	tensor(1.3327)
#
# iteration:	9784	loss:	tensor(1.3206)
#
# iteration:	9785	loss:	tensor(1.3383)
#
# iteration:	9786	loss:	tensor(1.3403)
#
# iteration:	9787	loss:	tensor(1.3913)
#
# iteration:	9788	loss:	tensor(1.3208)
#
# iteration:	9789	loss:	tensor(1.3166)
#
# iteration:	9790	loss:	tensor(1.3134)
#
# iteration:	9791	loss:	tensor(1.3114)
#
# iteration:	9792	loss:	tensor(1.3104)
#
# iteration:	9793	loss:	tensor(1.3161)
#
# iteration:	9794	loss:	tensor(1.3150)
#
# iteration:	9795	loss:	tensor(1.3177)
#
# iteration:	9796	loss:	tensor(1.3172)
#
# iteration:	9797	loss:	tensor(1.3373)
#
# iteration:	9798	loss:	tensor(1.3243)
#
# iteration:	9799	loss:	tensor(1.3579)
#
# iteration:	9800	loss:	tensor(1.3231)
#
# iteration:	9801	loss:	tensor(1.3345)
#
# iteration:	9802	loss:	tensor(1.3248)
#
# iteration:	9803	loss:	tensor(1.3382)
#
# iteration:	9804	loss:	tensor(1.3336)
#
# iteration:	9805	loss:	tensor(1.3421)
#
# iteration:	9806	loss:	tensor(1.3389)
#
# iteration:	9807	loss:	tensor(1.3358)
#
# iteration:	9808	loss:	tensor(1.3160)
#
# iteration:	9809	loss:	tensor(1.3134)
#
# iteration:	9810	loss:	tensor(1.3111)
#
# iteration:	9811	loss:	tensor(1.3156)
#
# iteration:	9812	loss:	tensor(1.3117)
#
# iteration:	9813	loss:	tensor(1.3178)
#
# iteration:	9814	loss:	tensor(1.3116)
#
# iteration:	9815	loss:	tensor(1.3178)
#
# iteration:	9816	loss:	tensor(1.3119)
#
# iteration:	9817	loss:	tensor(1.3173)
#
# iteration:	9818	loss:	tensor(1.3109)
#
# iteration:	9819	loss:	tensor(1.3147)
#
# iteration:	9820	loss:	tensor(1.3104)
#
# iteration:	9821	loss:	tensor(1.3150)
#
# iteration:	9822	loss:	tensor(1.3100)
#
# iteration:	9823	loss:	tensor(1.3142)
#
# iteration:	9824	loss:	tensor(1.3100)
#
# iteration:	9825	loss:	tensor(1.3146)
#
# iteration:	9826	loss:	tensor(1.3097)
#
# iteration:	9827	loss:	tensor(1.3136)
#
# iteration:	9828	loss:	tensor(1.3097)
#
# iteration:	9829	loss:	tensor(1.3144)
#
# iteration:	9830	loss:	tensor(1.3095)
#
# iteration:	9831	loss:	tensor(1.3145)
#
# iteration:	9832	loss:	tensor(1.3100)
#
# iteration:	9833	loss:	tensor(1.3162)
#
# iteration:	9834	loss:	tensor(1.3100)
#
# iteration:	9835	loss:	tensor(1.3148)
#
# iteration:	9836	loss:	tensor(1.3098)
#
# iteration:	9837	loss:	tensor(1.3149)
#
# iteration:	9838	loss:	tensor(1.3095)
#
# iteration:	9839	loss:	tensor(1.3135)
#
# iteration:	9840	loss:	tensor(1.3101)
#
# iteration:	9841	loss:	tensor(1.3168)
#
# iteration:	9842	loss:	tensor(1.3106)
#
# iteration:	9843	loss:	tensor(1.3157)
#
# iteration:	9844	loss:	tensor(1.3119)
#
# iteration:	9845	loss:	tensor(1.3190)
#
# iteration:	9846	loss:	tensor(1.3290)
#
# iteration:	9847	loss:	tensor(1.3167)
#
# iteration:	9848	loss:	tensor(1.3196)
#
# iteration:	9849	loss:	tensor(1.3166)
#
# iteration:	9850	loss:	tensor(1.3228)
#
# iteration:	9851	loss:	tensor(1.3329)
#
# iteration:	9852	loss:	tensor(1.3942)
#
# iteration:	9853	loss:	tensor(1.3348)
#
# iteration:	9854	loss:	tensor(1.3176)
#
# iteration:	9855	loss:	tensor(1.3193)
#
# iteration:	9856	loss:	tensor(1.3163)
#
# iteration:	9857	loss:	tensor(1.3196)
#
# iteration:	9858	loss:	tensor(1.3214)
#
# iteration:	9859	loss:	tensor(1.3304)
#
# iteration:	9860	loss:	tensor(1.3143)
#
# iteration:	9861	loss:	tensor(1.3119)
#
# iteration:	9862	loss:	tensor(1.3116)
#
# iteration:	9863	loss:	tensor(1.3123)
#
# iteration:	9864	loss:	tensor(1.3129)
#
# iteration:	9865	loss:	tensor(1.3125)
#
# iteration:	9866	loss:	tensor(1.3154)
#
# iteration:	9867	loss:	tensor(1.3149)
#
# iteration:	9868	loss:	tensor(1.3166)
#
# iteration:	9869	loss:	tensor(1.3197)
#
# iteration:	9870	loss:	tensor(1.3183)
#
# iteration:	9871	loss:	tensor(1.3224)
#
# iteration:	9872	loss:	tensor(1.3139)
#
# iteration:	9873	loss:	tensor(1.3166)
#
# iteration:	9874	loss:	tensor(1.3161)
#
# iteration:	9875	loss:	tensor(1.3259)
#
# iteration:	9876	loss:	tensor(1.3212)
#
# iteration:	9877	loss:	tensor(1.3403)
#
# iteration:	9878	loss:	tensor(1.3210)
#
# iteration:	9879	loss:	tensor(1.3290)
#
# iteration:	9880	loss:	tensor(1.3229)
#
# iteration:	9881	loss:	tensor(1.3332)
#
# iteration:	9882	loss:	tensor(1.3246)
#
# iteration:	9883	loss:	tensor(1.3409)
#
# iteration:	9884	loss:	tensor(1.3284)
#
# iteration:	9885	loss:	tensor(1.3585)
#
# iteration:	9886	loss:	tensor(1.3238)
#
# iteration:	9887	loss:	tensor(1.3379)
#
# iteration:	9888	loss:	tensor(1.3433)
#
# iteration:	9889	loss:	tensor(1.4245)
#
# iteration:	9890	loss:	tensor(1.3438)
#
# iteration:	9891	loss:	tensor(1.3140)
#
# iteration:	9892	loss:	tensor(1.3149)
#
# iteration:	9893	loss:	tensor(1.3099)
#
# iteration:	9894	loss:	tensor(1.3094)
#
# iteration:	9895	loss:	tensor(1.3094)
# iteration:	9896	loss:	tensor(1.3118)
#
# iteration:	9897	loss:	tensor(1.3125)
#
# iteration:	9898	loss:	tensor(1.3160)
#
# iteration:	9899	loss:	tensor(1.3185)
#
# iteration:	9900	loss:	tensor(1.3134)
#
# iteration:	9901	loss:	tensor(1.3130)
#
# iteration:	9902	loss:	tensor(1.3120)
#
# iteration:	9903	loss:	tensor(1.3149)
#
# iteration:	9904	loss:	tensor(1.3113)
#
# iteration:	9905	loss:	tensor(1.3106)
#
# iteration:	9906	loss:	tensor(1.3104)
#
# iteration:	9907	loss:	tensor(1.3105)
#
# iteration:	9908	loss:	tensor(1.3117)
#
# iteration:	9909	loss:	tensor(1.3115)
#
# iteration:	9910	loss:	tensor(1.3143)
#
# iteration:	9911	loss:	tensor(1.3192)
#
# iteration:	9912	loss:	tensor(1.3131)
#
# iteration:	9913	loss:	tensor(1.3095)
#
# iteration:	9914	loss:	tensor(1.3099)
#
# iteration:	9915	loss:	tensor(1.3117)
#
# iteration:	9916	loss:	tensor(1.3112)
#
# iteration:	9917	loss:	tensor(1.3127)
#
# iteration:	9918	loss:	tensor(1.3134)
#
# iteration:	9919	loss:	tensor(1.3158)
#
# iteration:	9920	loss:	tensor(1.3173)
#
# iteration:	9921	loss:	tensor(1.3235)
#
# iteration:	9922	loss:	tensor(1.3282)
#
# iteration:	9923	loss:	tensor(1.3412)
#
# iteration:	9924	loss:	tensor(1.3523)
#
# iteration:	9925	loss:	tensor(1.4267)
#
# iteration:	9926	loss:	tensor(1.3499)
#
# iteration:	9927	loss:	tensor(1.3159)
#
# iteration:	9928	loss:	tensor(1.3110)
#
# iteration:	9929	loss:	tensor(1.3104)
#
# iteration:	9930	loss:	tensor(1.3092)
#
# iteration:	9931	loss:	tensor(1.3148)
#
# iteration:	9932	loss:	tensor(1.3107)
#
# iteration:	9933	loss:	tensor(1.3183)
#
# iteration:	9934	loss:	tensor(1.3109)
#
# iteration:	9935	loss:	tensor(1.3143)
#
# iteration:	9936	loss:	tensor(1.3122)
#
# iteration:	9937	loss:	tensor(1.3155)
#
# iteration:	9938	loss:	tensor(1.3123)
#
# iteration:	9939	loss:	tensor(1.3135)
#
# iteration:	9940	loss:	tensor(1.3109)
#
# iteration:	9941	loss:	tensor(1.3126)
#
# iteration:	9942	loss:	tensor(1.3104)
#
# iteration:	9943	loss:	tensor(1.3140)
#
# iteration:	9944	loss:	tensor(1.3107)
#
# iteration:	9945	loss:	tensor(1.3120)
#
# iteration:	9946	loss:	tensor(1.3105)
#
# iteration:	9947	loss:	tensor(1.3131)
#
# iteration:	9948	loss:	tensor(1.3100)
#
# iteration:	9949	loss:	tensor(1.3140)
#
# iteration:	9950	loss:	tensor(1.3109)
#
# iteration:	9951	loss:	tensor(1.3136)
#
# iteration:	9952	loss:	tensor(1.3106)
#
# iteration:	9953	loss:	tensor(1.3139)
#
# iteration:	9954	loss:	tensor(1.3105)
#
# iteration:	9955	loss:	tensor(1.3134)
#
# iteration:	9956	loss:	tensor(1.3102)
#
# iteration:	9957	loss:	tensor(1.3126)
#
# iteration:	9958	loss:	tensor(1.3096)
#
# iteration:	9959	loss:	tensor(1.3125)
#
# iteration:	9960	loss:	tensor(1.3093)
#
# iteration:	9961	loss:	tensor(1.3125)
#
# iteration:	9962	loss:	tensor(1.3097)
#
# iteration:	9963	loss:	tensor(1.3131)
#
# iteration:	9964	loss:	tensor(1.3103)
#
# iteration:	9965	loss:	tensor(1.3140)
#
# iteration:	9966	loss:	tensor(1.3108)
#
# iteration:	9967	loss:	tensor(1.3140)
#
# iteration:	9968	loss:	tensor(1.3107)
#
# iteration:	9969	loss:	tensor(1.3132)
#
# iteration:	9970	loss:	tensor(1.3102)
#
# iteration:	9971	loss:	tensor(1.3127)
#
# iteration:	9972	loss:	tensor(1.3096)
#
# iteration:	9973	loss:	tensor(1.3123)
#
# iteration:	9974	loss:	tensor(1.3090)
#
# iteration:	9975	loss:	tensor(1.3114)
#
# iteration:	9976	loss:	tensor(1.3090)
#
# iteration:	9977	loss:	tensor(1.3128)
#
# iteration:	9978	loss:	tensor(1.3100)
#
# iteration:	9979	loss:	tensor(1.3144)
#
# iteration:	9980	loss:	tensor(1.3109)
#
# iteration:	9981	loss:	tensor(1.3150)
#
# iteration:	9982	loss:	tensor(1.3114)
#
# iteration:	9983	loss:	tensor(1.3144)
#
# iteration:	9984	loss:	tensor(1.3108)
#
# iteration:	9985	loss:	tensor(1.3132)
#
# iteration:	9986	loss:	tensor(1.3102)
#
# iteration:	9987	loss:	tensor(1.3132)
#
# iteration:	9988	loss:	tensor(1.3098)
#
# iteration:	9989	loss:	tensor(1.3128)
#
# iteration:	9990	loss:	tensor(1.3090)
#
# iteration:	9991	loss:	tensor(1.3110)
#
# iteration:	9992	loss:	tensor(1.3085)
#
# iteration:	9993	loss:	tensor(1.3118)
#
# iteration:	9994	loss:	tensor(1.3098)
#
# iteration:	9995	loss:	tensor(1.3142)
#
# iteration:	9996	loss:	tensor(1.3123)
#
# iteration:	9997	loss:	tensor(1.3155)
#
# iteration:	9998	loss:	tensor(1.3129)
#
# iteration:	9999	loss:	tensor(1.3133)

# %%
# 测试集上数据预处理和降维
val_set = val_set.reshape((1000,3072))
val_set = val_set - np.mean(val_set, axis=0)
val_set = val_set / np.std(val_set, axis=0)
cov = np.dot(val_set.T,val_set) / val_set.shape[0]
U,S,V = np.linalg.svd(cov)
val_set = np.dot(val_set,U[:,:144])


# 在测试集上测试
val_set = torch.tensor(val_set, dtype=torch.float32)
val_labels = torch.tensor(val_labels, dtype=torch.long)

out = net(val_set)
prediction = torch.max(F.softmax(out),1)[1]
pred_y = prediction.data.numpy().squeeze()
target_y = val_labels.data.numpy()
print('accuracy in val:\t%s' % (np.sum(target_y == pred_y)))
# Out:
# accuracy in val:	\s
# E:\Anaconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   del sys.path[0]
# E:\Anaconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
